# %%
# Import libraries
from collections import Counter, OrderedDict
from itertools import chain
from keras.layers import Input, Embedding, Dot, Reshape, Dense, Concatenate, Multiply
from keras.models import Model
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 500)
pd.options.display.max_colwidth = 1000
import random
import tensorflow as tf
from tensorflow.keras import models
import pandas as pd
# Import libraries
from collections import Counter, OrderedDict
# import datawig
from itertools import chain
from keras.layers import Input, Embedding, Add, Reshape, Dense, Multiply, GlobalMaxPool1D, Dot
from keras.models import Model
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 500)
pd.options.display.max_colwidth = 1000
import random

# %%
# Path to file
#kaggle datasets download -d leticiacruz/hotelsitems
hotels_df = pd.read_csv("../input/hotelsitems/hotels_com_scrape_v3.csv", header=None)
hotels_df.head()
# Out:
#                       0                                      1    2    3  \
# 0  Mutterstadt, Germany                        RheinCity Hotel  4.0    4
# 1  Mutterstadt, Germany  NYX Hotel Mannheim by Leonardo Hotels  4.0   14
# 2  Mutterstadt, Germany           Radisson Blu Hotel, Mannheim  4.5  387
# 3  Mutterstadt, Germany        ACHAT Comfort Frankenthal/Pfalz  3.5   64
# 4  Mutterstadt, Germany                        Relax Apartment   na   na
#
#                                                     4             5  \
# 0  Zollhofstraße 11, Ludwigshafen, RP, 67059, Germany  Ludwigshafen
# 1              F4, 4-11, Mannheim, BW, 68159, Germany      Mannheim
# 2           Quadrant Q7, 27, Mannheim, 68161, Germany      Mannheim
# 3    Mahlastrasse 18, Frankenthal, RP, 67227, Germany   Frankenthal
# 4                  F4 14-15, Mannheim, 68159, Germany      Mannheim
#
#                                                        6      7  \
# 0  5.4 miles to Mutterstadt, 3.3 miles to Mannheim (MHG)  107.0
# 1  6.2 miles to Mutterstadt, 2.8 miles to Mannheim (MHG)   78.0
# 2  6.4 miles to Mutterstadt, 2.3 miles to Mannheim (MHG)     na
# 3  5.9 miles to Mutterstadt, 8.3 miles to Mannheim (MHG)   83.0
# 4  6.2 miles to Mutterstadt, 2.7 miles to Mannheim (MHG)     na
#
#                                                                                                                                                                                               8
# 0  https://www.hotels.com/ho804141952/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=1&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 1     https://www.hotels.com/ho408334/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=2&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 2                                                                 https://www.hotels.com/ho626280/?pa=3&tab=description&q-room-0-adults=2&intlid=SoldOutListing&ZSX=0&SYE=3&q-room-0-children=0
# 3     https://www.hotels.com/ho180949/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=4&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 4     https://www.hotels.com/ho685840/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=5&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3

# %%
hotels_df[hotels_df['city']=='stralsund']
# Out:
# Empty DataFrame
# Columns: [city, country, hotel_name, rating, address, locality, price, landmark, URL]
# Index: []

# %%
hotels_df
# Out:
#                           0                                        1    2  \
# 0      Mutterstadt, Germany                          RheinCity Hotel  4.0
# 1      Mutterstadt, Germany    NYX Hotel Mannheim by Leonardo Hotels  4.0
# 2      Mutterstadt, Germany             Radisson Blu Hotel, Mannheim  4.5
# 3      Mutterstadt, Germany          ACHAT Comfort Frankenthal/Pfalz  3.5
# 4      Mutterstadt, Germany                          Relax Apartment   na
# ...                     ...                                      ...  ...
# 19816        Hadera, Israel         Haifa Luxury Boutique Apartments  4.5
# 19817        Hadera, Israel        Yam Hotel An Atlas Boutique Hotel  5.0
# 19818        Hadera, Israel             Etty's Hous - Boutique Hotel   na
# 19819        Hadera, Israel  Port and Blue TLV Boutique Suites Hotel  4.5
# 19820        Hadera, Israel                               Isra Hotel  4.5
#
#          3  \
# 0        4
# 1       14
# 2      387
# 3       64
# 4       na
# ...    ...
# 19816    8
# 19817  918
# 19818   na
# 19819  380
# 19820    9
#
#                                                                                              4  \
# 0                                           Zollhofstraße 11, Ludwigshafen, RP, 67059, Germany
# 1                                                       F4, 4-11, Mannheim, BW, 68159, Germany
# 2                                                    Quadrant Q7, 27, Mannheim, 68161, Germany
# 3                                             Mahlastrasse 18, Frankenthal, RP, 67227, Germany
# 4                                                           F4 14-15, Mannheim, 68159, Germany
# ...                                                                                        ...
# 19816                                                            Sderot Sinai 1, Haifa, Israel
# 19817                                      16 Yordei Ha-Sira Street, Tel Aviv, 6350818, Israel
# 19818  69 Degel Re'uven St, 69 Degel Re'uven St, Petah Tikva, Center District, 4955163, Israel
# 19819                                                      Tsidon 1, Tel Aviv, 6350835, Israel
# 19820                                           Sufian Street, Nablus, Palestinian Territories
#
#                                      5  \
# 0                         Ludwigshafen
# 1                             Mannheim
# 2                             Mannheim
# 3                          Frankenthal
# 4                             Mannheim
# ...                                ...
# 19816                            Haifa
# 19817                         Tel Aviv
# 19818                      Petah Tikva
# 19819                         Tel Aviv
# 19820  Nablus, Palestinian Territories
#
#                                                              6      7  \
# 0        5.4 miles to Mutterstadt, 3.3 miles to Mannheim (MHG)  107.0
# 1        6.2 miles to Mutterstadt, 2.8 miles to Mannheim (MHG)   78.0
# 2        6.4 miles to Mutterstadt, 2.3 miles to Mannheim (MHG)     na
# 3        5.9 miles to Mutterstadt, 8.3 miles to Mannheim (MHG)   83.0
# 4        6.2 miles to Mutterstadt, 2.7 miles to Mannheim (MHG)     na
# ...                                                        ...    ...
# 19816   25 miles to Hadera, 48 miles to Tel Aviv (SDV-Sde Dov)     na
# 19817  25 miles to Hadera, 0.9 miles to Tel Aviv (SDV-Sde Dov)  202.0
# 19818  25 miles to Hadera, 5.3 miles to Tel Aviv (SDV-Sde Dov)  136.0
# 19819  25 miles to Hadera, 0.9 miles to Tel Aviv (SDV-Sde Dov)  169.0
# 19820   25 miles to Hadera, 29 miles to Tel Aviv (SDV-Sde Dov)     na
#
#                                                                                                                                                                                                     8
# 0        https://www.hotels.com/ho804141952/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=1&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 1           https://www.hotels.com/ho408334/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=2&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 2                                                                       https://www.hotels.com/ho626280/?pa=3&tab=description&q-room-0-adults=2&intlid=SoldOutListing&ZSX=0&SYE=3&q-room-0-children=0
# 3           https://www.hotels.com/ho180949/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=4&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 4           https://www.hotels.com/ho685840/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=5&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# ...                                                                                                                                                                                               ...
# 19816      https://www.hotels.com/ho515590/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=33&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 19817      https://www.hotels.com/ho512336/?q-check-out=2020-08-29&FPQ=4&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=34&tab=description&JHR=5&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 19818  https://www.hotels.com/ho1081551456/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=35&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 19819      https://www.hotels.com/ho554424/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=36&tab=description&JHR=4&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 19820  https://www.hotels.com/ho1017244672/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=37&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
#
# [19821 rows x 9 columns]

# %%
hotels_df.rename({0: "location", 1: "hotel_name", 2: "rating", 3: "popularity_rating", 
                      4: "address", 5: "locality", 6: "landmark", 
                      7: "price", 8: "URL"}, inplace = True, axis = 1)

# %%
# Split location
location_df = hotels_df["location"].str.split(",", expand = True)

# Rename landmark columns
location_df.rename({0: "city", 1: "country"}, inplace = True, axis = 1)

# Merge landmarks_df with hotels_df
hotels_df = pd.merge(location_df, hotels_df[["hotel_name", "rating", "address",
                                             "locality", "price", "landmark", "URL"]], left_index = True, 
                          right_index = True, how = "right")

# %%
hotels_df
# Out:
#               city   country                               hotel_name rating  \
# 0      Mutterstadt   Germany                          RheinCity Hotel    4.0
# 1      Mutterstadt   Germany    NYX Hotel Mannheim by Leonardo Hotels    4.0
# 2      Mutterstadt   Germany             Radisson Blu Hotel, Mannheim    4.5
# 3      Mutterstadt   Germany          ACHAT Comfort Frankenthal/Pfalz    3.5
# 4      Mutterstadt   Germany                          Relax Apartment     na
# ...            ...       ...                                      ...    ...
# 19816       Hadera    Israel         Haifa Luxury Boutique Apartments    4.5
# 19817       Hadera    Israel        Yam Hotel An Atlas Boutique Hotel    5.0
# 19818       Hadera    Israel             Etty's Hous - Boutique Hotel     na
# 19819       Hadera    Israel  Port and Blue TLV Boutique Suites Hotel    4.5
# 19820       Hadera    Israel                               Isra Hotel    4.5
#
#                                                                                        address  \
# 0                                           Zollhofstraße 11, Ludwigshafen, RP, 67059, Germany
# 1                                                       F4, 4-11, Mannheim, BW, 68159, Germany
# 2                                                    Quadrant Q7, 27, Mannheim, 68161, Germany
# 3                                             Mahlastrasse 18, Frankenthal, RP, 67227, Germany
# 4                                                           F4 14-15, Mannheim, 68159, Germany
# ...                                                                                        ...
# 19816                                                            Sderot Sinai 1, Haifa, Israel
# 19817                                      16 Yordei Ha-Sira Street, Tel Aviv, 6350818, Israel
# 19818  69 Degel Re'uven St, 69 Degel Re'uven St, Petah Tikva, Center District, 4955163, Israel
# 19819                                                      Tsidon 1, Tel Aviv, 6350835, Israel
# 19820                                           Sufian Street, Nablus, Palestinian Territories
#
#                               locality  price  \
# 0                         Ludwigshafen  107.0
# 1                             Mannheim   78.0
# 2                             Mannheim     na
# 3                          Frankenthal   83.0
# 4                             Mannheim     na
# ...                                ...    ...
# 19816                            Haifa     na
# 19817                         Tel Aviv  202.0
# 19818                      Petah Tikva  136.0
# 19819                         Tel Aviv  169.0
# 19820  Nablus, Palestinian Territories     na
#
#                                                       landmark  \
# 0        5.4 miles to Mutterstadt, 3.3 miles to Mannheim (MHG)
# 1        6.2 miles to Mutterstadt, 2.8 miles to Mannheim (MHG)
# 2        6.4 miles to Mutterstadt, 2.3 miles to Mannheim (MHG)
# 3        5.9 miles to Mutterstadt, 8.3 miles to Mannheim (MHG)
# 4        6.2 miles to Mutterstadt, 2.7 miles to Mannheim (MHG)
# ...                                                        ...
# 19816   25 miles to Hadera, 48 miles to Tel Aviv (SDV-Sde Dov)
# 19817  25 miles to Hadera, 0.9 miles to Tel Aviv (SDV-Sde Dov)
# 19818  25 miles to Hadera, 5.3 miles to Tel Aviv (SDV-Sde Dov)
# 19819  25 miles to Hadera, 0.9 miles to Tel Aviv (SDV-Sde Dov)
# 19820   25 miles to Hadera, 29 miles to Tel Aviv (SDV-Sde Dov)
#
#                                                                                                                                                                                                   URL
# 0        https://www.hotels.com/ho804141952/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=1&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 1           https://www.hotels.com/ho408334/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=2&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 2                                                                       https://www.hotels.com/ho626280/?pa=3&tab=description&q-room-0-adults=2&intlid=SoldOutListing&ZSX=0&SYE=3&q-room-0-children=0
# 3           https://www.hotels.com/ho180949/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=4&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 4           https://www.hotels.com/ho685840/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=5&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# ...                                                                                                                                                                                               ...
# 19816      https://www.hotels.com/ho515590/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=33&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 19817      https://www.hotels.com/ho512336/?q-check-out=2020-08-29&FPQ=4&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=34&tab=description&JHR=5&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 19818  https://www.hotels.com/ho1081551456/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=35&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 19819      https://www.hotels.com/ho554424/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=36&tab=description&JHR=4&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 19820  https://www.hotels.com/ho1017244672/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=37&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
#
# [19821 rows x 9 columns]

# %%
# Prepare city column

# Convert all cities to lowercase
hotels_df["city"] = hotels_df["city"].apply(lambda x: x.lower())

city_list = hotels_df["city"].tolist()

# Find set of unique cities and convert to a list
unique_cities = list(set(city_list))

# Create indexes for each city
city_index = {city: idx for idx, city in enumerate(unique_cities)}
index_city = {idx: city for city, idx in city_index.items()}

# %%
# Prepare country column

# Convert all countries to lowercase
hotels_df["country"] = hotels_df["country"].apply(lambda x: x.lower())

country_list = hotels_df["country"].tolist()

# Find set of unique countries and convert to a list
unique_countries = list(set(country_list))

# Create indexes for each property
country_index = {country: idx for idx, country in enumerate(unique_countries)}
index_country = {idx: country for country, idx in country_index.items()}

# %%
# Prepare hotel_name column

# Convert all hotels to lowercase
hotels_df["hotel_name"] = hotels_df["hotel_name"].apply(lambda x: x.lower())

# Create hotel names list
hotels_list = hotels_df["hotel_name"].tolist()

# Unique hotels
unique_hotels = list(set(hotels_list))

# Create indexes for each hotel
hotel_index = {hotel: idx for idx, hotel in enumerate(unique_hotels)}
index_hotel = {idx: hotel for hotel, idx in hotel_index.items()}

# %%
# Create ratings list
rating_list = hotels_df["rating"].tolist()

# Find set of unique ratings and convert to a list
unique_ratings = list(set(rating_list))

# Create indexes for each rating
rating_index = {rating: idx for idx, rating in enumerate(unique_ratings)}
index_rating = {idx: rating for rating, idx in rating_index.items()}

# %%
# Prepare locality column

# Convert all hotels to lowercase
hotels_df["locality"] = hotels_df["locality"].apply(lambda x: x.lower())

# Create hotel names list
locality_list = hotels_df["locality"].tolist()
unique_localities = list(set(locality_list))

# Create indexes for each hotel
locality_index = {locality: idx for idx, locality in enumerate(unique_localities)}
index_locality = {idx: locality for locality, idx in locality_index.items()}

# %%
# Create price list
price_list = hotels_df["price"].tolist()

# Unique prices
unique_prices = list(set(price_list))

# Create indexes for each price
price_index = {price: idx for idx, price in enumerate(unique_prices)}
index_price = {idx: price for price, idx in price_index.items()}

# %%
# Convert all landmarks to strings
hotels_df["landmark"] = hotels_df["landmark"].apply(lambda x: str(x))

# Convert all landmarks to lowercase
hotels_df["landmark"] = hotels_df["landmark"].apply(lambda x: x.lower())

# Split landmark
hotels_df["landmark"] = hotels_df["landmark"].str.split("\n")

# %%
# Prepare locality column

# Create hotel names list
landmark_list = hotels_df["landmark"].tolist()

# Find set of unique properties and convert to a list
#unique_landmarks = list(chain(*[list(set(landmarks)) for landmarks in landmark_list]))
#unique_landmarks = list(np.unique(landmark_list))
unique_landmarks = list(chain(*[list(set(landmarks)) for landmarks in landmark_list]))
unique_landmarks = list(set(unique_landmarks))


# Create indexes for each hotel
landmark_index = {landmark: idx for idx, landmark in enumerate(unique_landmarks)}
index_landmark = {idx: landmark for landmark, idx in landmark_index.items()}

# %%
# Build tuples to train embedding neural network
hotel_tuples = []

# Iterate through each row of dataframe
for index, row in hotels_df.iterrows():
    # Iterate through the properties in the item
    hotel_tuples.extend((city_index[hotels_df.at[index, "city"]], country_index[hotels_df.at[index, "country"]],
                         hotel_index[hotels_df.at[index, "hotel_name"]], rating_index[hotels_df.at[index, "rating"]],

                         locality_index[hotels_df.at[index, "locality"]], 
                         price_index[hotels_df.at[index, "price"]], landmark_index[landmark]) for landmark in hotels_df.at[index, "landmark"] if landmark.lower() in unique_landmarks)

# %%
# Generator for training samples
def generate_batch(tuples, n_positive = 75, negative_ratio = 2.0):
    
    pairs_set = set(tuples)
    
    batch_size = n_positive * (1 + negative_ratio)
    batch = np.zeros((batch_size, 8))
    
    # Label for negative examples
    neg_label = 0
    
    # This creates a generator
    while True:
        # randomly choose positive examples
        for idx, (city_id, country_id, hotel_id, rating_id, locality_id, price_id, landmark_id) in enumerate(random.sample(tuples, n_positive)):
            batch[idx, :] = (city_id, country_id, hotel_id, rating_id, locality_id, price_id, landmark_id, 1)

        # Increment idx by 1
        idx += 1
        
        # Add negative examples until reach batch size
        while idx < batch_size:
            
            # random selection
            random_city = random.randrange(len(unique_cities))
            random_country = random.randrange(len(unique_countries))
            random_hotel = random.randrange(len(unique_hotels))
            random_rating = random.randrange(len(unique_ratings))
            random_locality = random.randrange(len(unique_localities))
            random_price = random.randrange(len(unique_prices))
            random_landmark = random.randrange(len(unique_landmarks))
            
            # Check to make sure this is not a positive example
            if (random_city, random_country, random_hotel, random_rating, random_locality,
               random_price, random_landmark) not in pairs_set:
                
                # Add to batch and increment index
                batch[idx, :] = (random_city, random_country, random_hotel, random_rating, random_locality,
                                   random_price, random_landmark, neg_label)
                idx += 1
                
        # Make sure to shuffle order
        np.random.shuffle(batch)
        yield {"city": batch[:, 0], "country": batch[:, 1], "hotel": batch[:, 2], 
               "rating": batch[:, 3], "locality": batch[:, 4], 
               "price": batch[:, 5], "landmark": batch[:, 6]}, batch[:, 7]

# %%
# Properties embedding model
def hotel_embeddings(embedding_size = 50):
    
    # Inputs are one-dimensional
    city = Input(name = "city", shape = [1])
    country = Input(name = "country", shape = [1])
    hotel = Input(name = "hotel", shape = [1])
    rating = Input(name = "rating", shape = [1])
    locality = Input(name = "locality", shape = [1])
    price = Input(name = "price", shape = [1])
    landmark = Input(name = "landmark", shape = [1])
    
    # Embedding the city
    city_embedding = Embedding(name = "city_embedding", input_dim = len(city_index), 
                              output_dim = embedding_size)(city)
    
    # Embedding the country
    country_embedding = Embedding(name = "country_embedding", input_dim = len(country_index),
                                  output_dim = embedding_size)(country)
    
    # Embedding the hotel
    hotel_embedding = Embedding(name = "hotel_embedding", input_dim = len(hotel_index),
                                  output_dim = embedding_size)(hotel)
    
    # Embedding the rating
    rating_embedding = Embedding(name = "rating_embedding", input_dim = len(rating_index),
                                  output_dim = embedding_size)(rating)  
    
    # Embedding the locality
    locality_embedding = Embedding(name = "locality_embedding", input_dim = len(locality_index),
                                  output_dim = embedding_size)(locality)
    
    # Embedding the price
    price_embedding = Embedding(name = "price_embedding", input_dim = len(price_index),
                                  output_dim = embedding_size)(price)
    
    # Embedding the landmark
    landmark_embedding = Embedding(name = "landmark_embedding", input_dim = len(landmark_index),
                                  output_dim = embedding_size)(landmark)
    
    
    # Merge the embeddings with multiplication 
    merged_one = Multiply(name = "interaction_one")([city_embedding, country_embedding])
    merged_two = Multiply(name = "interaction_two")([city_embedding, hotel_embedding])
    merged_three = Multiply(name = "interaction_three")([city_embedding, rating_embedding])
    merged_four = Multiply(name = "interaction_four")([city_embedding, locality_embedding])
    merged_five = Multiply(name = "interaction_five")([city_embedding, price_embedding])
    merged_six = Multiply(name = "interaction_six")([city_embedding, landmark_embedding])
    merged_seven = Multiply(name = "interaction_seven")([country_embedding, hotel_embedding])
    merged_eight = Multiply(name = "interaction_eight")([country_embedding, rating_embedding])
    merged_nine = Multiply(name = "interaction_nine")([country_embedding, locality_embedding])
    merged_ten = Multiply(name = "interaction_ten")([country_embedding, price_embedding])
    merged_eleven = Multiply(name = "interaction_eleven")([country_embedding, landmark_embedding])
    merged_twelve = Multiply(name = "interaction_twelve")([hotel_embedding, rating_embedding])  
    merged_thirteen = Multiply(name = "interaction_thirteen")([hotel_embedding, locality_embedding])  
    merged_fourteen = Multiply(name = "interaction_fourteen")([hotel_embedding, price_embedding])  
    merged_fifteen = Multiply(name = "interaction_fifteen")([hotel_embedding, landmark_embedding])  
    merged_sixteen = Multiply(name = "interaction_sixteen")([rating_embedding, locality_embedding])  
    merged_seventeen = Multiply(name = "interaction_seventeen")([rating_embedding, price_embedding])  
    merged_eighteen = Multiply(name = "interaction_eighteen")([rating_embedding, landmark_embedding])  
    merged_nineteen = Multiply(name = "interaction_nineteen")([locality_embedding, price_embedding])  
    merged_twenty = Multiply(name = "interaction_twenty")([locality_embedding, landmark_embedding])
    merged_twentyone = Multiply(name = "interaction_twentyone")([price_embedding, landmark_embedding])
#    merged_twentytwo = Multiply(name = "interaction_twentytwo")([popularity_embedding, city_embedding])
#    merged_twentythree = Multiply(name = "interaction_twentythree")([popularity_embedding, country_embedding])
#    merged_twentyfour = Multiply(name = "interaction_twentyfour")([popularity_embedding, hotel_embedding])
#    merged_twentyfive = Multiply(name = "interaction_twentyfive")([popularity_embedding, rating_embedding])
#    merged_twentysix = Multiply(name = "interaction_twentysix")([popularity_embedding, locality_embedding])
#    merged_twentyseven = Multiply(name = "interaction_twentyseven")([popularity_embedding, price_embedding])
#    merged_twentyeight = Multiply(name = "interaction_twentyeight")([popularity_embedding, landmark_embedding])
    
    # GlobalMaxPool
    pooling_one = GlobalMaxPool1D(name = "pooling_one")(merged_one)
    pooling_two = GlobalMaxPool1D(name = "pooling_two")(merged_two)
    pooling_three = GlobalMaxPool1D(name = "pooling_three")(merged_three)
    pooling_four = GlobalMaxPool1D(name = "pooling_four")(merged_four)
    pooling_five = GlobalMaxPool1D(name = "pooling_five")(merged_five)
    pooling_six = GlobalMaxPool1D(name = "pooling_six")(merged_six)    
    pooling_seven = GlobalMaxPool1D(name = "pooling_seven")(merged_seven)
    pooling_eight = GlobalMaxPool1D(name = "pooling_eight")(merged_eight)   
    pooling_nine = GlobalMaxPool1D(name = "pooling_nine")(merged_nine)   
    pooling_ten = GlobalMaxPool1D(name = "pooling_ten")(merged_ten)    
    pooling_eleven = GlobalMaxPool1D(name = "pooling_eleven")(merged_eleven)    
    pooling_twelve = GlobalMaxPool1D(name = "pooling_twelve")(merged_twelve)  
    pooling_thirteen = GlobalMaxPool1D(name = "pooling_thirteen")(merged_thirteen)
    pooling_fourteen = GlobalMaxPool1D(name = "pooling_fourteen")(merged_fourteen)
    pooling_fifteen = GlobalMaxPool1D(name = "pooling_fifteen")(merged_fifteen)
    pooling_sixteen = GlobalMaxPool1D(name = "pooling_sixteen")(merged_sixteen)
    pooling_seventeen = GlobalMaxPool1D(name = "pooling_seventeen")(merged_seventeen)
    pooling_eighteen = GlobalMaxPool1D(name = "pooling_eighteen")(merged_eighteen)
    pooling_nineteen = GlobalMaxPool1D(name = "pooling_nineteen")(merged_nineteen)
    pooling_twenty = GlobalMaxPool1D(name = "pooling_twenty")(merged_twenty)
    pooling_twentyone = GlobalMaxPool1D(name = "pooling_twentyone")(merged_twentyone)
    #pooling_twentytwo = GlobalMaxPool1D(name = "pooling_twentytwo")(merged_twentytwo)
    #pooling_twentythree = GlobalMaxPool1D(name = "pooling_twentythree")(merged_twentythree)
    #pooling_twentyfour = GlobalMaxPool1D(name = "pooling_twentyfour")(merged_twentyfour)
    #pooling_twentyfive = GlobalMaxPool1D(name = "pooling_twentyfive")(merged_twentyfive)
    #pooling_twentysix = GlobalMaxPool1D(name = "pooling_twentysix")(merged_twentysix)
    #pooling_twentyseven = GlobalMaxPool1D(name = "pooling_twentyseven")(merged_twentyseven)
    #pooling_twentyeight = GlobalMaxPool1D(name = "pooling_twentyeight")(merged_twentyeight)
    
    # Dot Product
    dot_1 = Dot(normalize = True, axes = -1)([pooling_one, pooling_two])
    dot_2 = Dot(normalize = True, axes = -1)([pooling_one, pooling_three])
    dot_3 = Dot(normalize = True, axes = -1)([pooling_one, pooling_four])
    dot_4 = Dot(normalize = True, axes = -1)([pooling_one, pooling_five])
    dot_5 = Dot(normalize = True, axes = -1)([pooling_one, pooling_six])
    dot_6 = Dot(normalize = True, axes = -1)([pooling_one, pooling_seven])
    dot_7 = Dot(normalize = True, axes = -1)([pooling_one, pooling_eight])
    dot_8 = Dot(normalize = True, axes = -1)([pooling_one, pooling_nine])
    dot_9 = Dot(normalize = True, axes = -1)([pooling_one, pooling_ten])
    dot_10 = Dot(normalize = True, axes = -1)([pooling_one, pooling_eleven])
    dot_11 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twelve])
    dot_12 = Dot(normalize = True, axes = -1)([pooling_one, pooling_thirteen])
    dot_13 = Dot(normalize = True, axes = -1)([pooling_one, pooling_fourteen])
    dot_14 = Dot(normalize = True, axes = -1)([pooling_one, pooling_fifteen])
    dot_15 = Dot(normalize = True, axes = -1)([pooling_one, pooling_sixteen])
    dot_16 = Dot(normalize = True, axes = -1)([pooling_one, pooling_seventeen])
    dot_17 = Dot(normalize = True, axes = -1)([pooling_one, pooling_eighteen])
    dot_18 = Dot(normalize = True, axes = -1)([pooling_one, pooling_nineteen])
    dot_19 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twenty])
    dot_20 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twentyone])
    #dot_21 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twentytwo])
    #dot_22 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twentythree])
    #dot_23 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twentyfour])
    #dot_24 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twentyfive])    
    #dot_25 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twentysix])    
    #dot_26 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twentyseven])    
    #dot_27 = Dot(normalize = True, axes = -1)([pooling_one, pooling_twentyeight])    
    dot_28 = Dot(normalize = True, axes = -1)([pooling_two, pooling_three])    
    dot_29 = Dot(normalize = True, axes = -1)([pooling_two, pooling_four])   
    dot_30 = Dot(normalize = True, axes = -1)([pooling_two, pooling_five])   
    dot_31 = Dot(normalize = True, axes = -1)([pooling_two, pooling_six])   
    dot_32 = Dot(normalize = True, axes = -1)([pooling_two, pooling_seven])   
    dot_33 = Dot(normalize = True, axes = -1)([pooling_two, pooling_eight])   
    dot_34 = Dot(normalize = True, axes = -1)([pooling_two, pooling_nine])   
    dot_35 = Dot(normalize = True, axes = -1)([pooling_two, pooling_ten])   
    dot_36 = Dot(normalize = True, axes = -1)([pooling_two, pooling_eleven])   
    dot_37 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twelve])   
    dot_38 = Dot(normalize = True, axes = -1)([pooling_two, pooling_thirteen])   
    dot_39 = Dot(normalize = True, axes = -1)([pooling_two, pooling_fourteen])   
    dot_40 = Dot(normalize = True, axes = -1)([pooling_two, pooling_fifteen])   
    dot_41 = Dot(normalize = True, axes = -1)([pooling_two, pooling_sixteen])   
    dot_42 = Dot(normalize = True, axes = -1)([pooling_two, pooling_seventeen])   
    dot_43 = Dot(normalize = True, axes = -1)([pooling_two, pooling_eighteen]) 
    dot_44 = Dot(normalize = True, axes = -1)([pooling_two, pooling_nineteen]) 
    dot_45 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twenty]) 
    dot_46 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twentyone]) 
    #dot_47 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twentytwo]) 
    #dot_48 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twentythree]) 
    #dot_49 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twentyfour]) 
    #dot_50 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twentyfive]) 
    #dot_51 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twentysix]) 
    #dot_52 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twentyseven]) 
    #dot_53 = Dot(normalize = True, axes = -1)([pooling_two, pooling_twentyeight]) 
    dot_54 = Dot(normalize = True, axes = -1)([pooling_three, pooling_four])    
    dot_55 = Dot(normalize = True, axes = -1)([pooling_three, pooling_five]) 
    dot_56 = Dot(normalize = True, axes = -1)([pooling_three, pooling_six]) 
    dot_57 = Dot(normalize = True, axes = -1)([pooling_three, pooling_seven]) 
    dot_58 = Dot(normalize = True, axes = -1)([pooling_three, pooling_eight]) 
    dot_59 = Dot(normalize = True, axes = -1)([pooling_three, pooling_nine]) 
    dot_60 = Dot(normalize = True, axes = -1)([pooling_three, pooling_ten]) 
    dot_61 = Dot(normalize = True, axes = -1)([pooling_three, pooling_eleven]) 
    dot_62 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twelve]) 
    dot_63 = Dot(normalize = True, axes = -1)([pooling_three, pooling_thirteen]) 
    dot_64 = Dot(normalize = True, axes = -1)([pooling_three, pooling_fourteen]) 
    dot_65 = Dot(normalize = True, axes = -1)([pooling_three, pooling_fifteen]) 
    dot_66 = Dot(normalize = True, axes = -1)([pooling_three, pooling_sixteen]) 
    dot_67 = Dot(normalize = True, axes = -1)([pooling_three, pooling_seventeen]) 
    dot_68 = Dot(normalize = True, axes = -1)([pooling_three, pooling_eighteen]) 
    dot_69 = Dot(normalize = True, axes = -1)([pooling_three, pooling_nineteen]) 
    dot_70 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twenty])
    dot_71 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twentyone])
    #dot_72 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twentytwo])
    #dot_73 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twentythree])
    #dot_74 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twentyfour])
    #dot_75 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twentyfive])
    #dot_76 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twentysix])
    #dot_77 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twentyseven])
    #dot_78 = Dot(normalize = True, axes = -1)([pooling_three, pooling_twentyeight])
    dot_79 = Dot(normalize = True, axes = -1)([pooling_four, pooling_five])
    dot_80 = Dot(normalize = True, axes = -1)([pooling_four, pooling_six])
    dot_81 = Dot(normalize = True, axes = -1)([pooling_four, pooling_seven])
    dot_82 = Dot(normalize = True, axes = -1)([pooling_four, pooling_eight])
    dot_83 = Dot(normalize = True, axes = -1)([pooling_four, pooling_nine])
    dot_84 = Dot(normalize = True, axes = -1)([pooling_four, pooling_ten])
    dot_85 = Dot(normalize = True, axes = -1)([pooling_four, pooling_eleven])
    dot_86 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twelve])
    dot_87 = Dot(normalize = True, axes = -1)([pooling_four, pooling_thirteen])
    dot_88 = Dot(normalize = True, axes = -1)([pooling_four, pooling_fourteen])
    dot_89 = Dot(normalize = True, axes = -1)([pooling_four, pooling_fifteen])
    dot_90 = Dot(normalize = True, axes = -1)([pooling_four, pooling_sixteen])
    dot_91 = Dot(normalize = True, axes = -1)([pooling_four, pooling_seventeen])
    dot_92 = Dot(normalize = True, axes = -1)([pooling_four, pooling_eighteen])
    dot_93 = Dot(normalize = True, axes = -1)([pooling_four, pooling_nineteen])
    dot_94 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twenty])
    dot_95 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twentyone])
    #dot_96 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twentytwo])
    #dot_97 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twentythree])
    #dot_98 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twentyfour])
    #dot_99 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twentyfive])
    #dot_100 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twentysix])
    #dot_101 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twentyseven])
    #dot_102 = Dot(normalize = True, axes = -1)([pooling_four, pooling_twentyeight])
    dot_103 = Dot(normalize = True, axes = -1)([pooling_five, pooling_six])
    dot_104 = Dot(normalize = True, axes = -1)([pooling_five, pooling_seven])
    dot_105 = Dot(normalize = True, axes = -1)([pooling_five, pooling_eight])
    dot_106 = Dot(normalize = True, axes = -1)([pooling_five, pooling_nine])
    dot_107 = Dot(normalize = True, axes = -1)([pooling_five, pooling_ten])
    dot_108 = Dot(normalize = True, axes = -1)([pooling_five, pooling_eleven])
    dot_109 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twelve])
    dot_110 = Dot(normalize = True, axes = -1)([pooling_five, pooling_thirteen])
    dot_111 = Dot(normalize = True, axes = -1)([pooling_five, pooling_fourteen])
    dot_112 = Dot(normalize = True, axes = -1)([pooling_five, pooling_fifteen])
    dot_113 = Dot(normalize = True, axes = -1)([pooling_five, pooling_sixteen])
    dot_114 = Dot(normalize = True, axes = -1)([pooling_five, pooling_seventeen])
    dot_116 = Dot(normalize = True, axes = -1)([pooling_five, pooling_eighteen])
    dot_117 = Dot(normalize = True, axes = -1)([pooling_five, pooling_nineteen])
    dot_118 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twenty])
    dot_119 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twentyone])
    #dot_120 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twentyfour])
    #dot_121 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twentyfive])
    #dot_122 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twentysix])
    #dot_123 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twentyseven])
    #dot_124 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twentyeight])
    dot_125 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_eight])
    dot_126 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_nine])
    dot_127 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_ten])
    dot_128 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_eleven])
    dot_129 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twelve])
    dot_130 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_thirteen])
    dot_131 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_fourteen])
    dot_132 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_fifteen])
    dot_133 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_sixteen])
    dot_134 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_seventeen])
    dot_135 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_eighteen])
    dot_136 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_nineteen])
    dot_137 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twenty])
    dot_138 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twentyone])
    #dot_139 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twentytwo])
    #dot_140 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twentythree])
    #dot_141 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twentyfour])
    #dot_142 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twentyfive])
    #dot_143 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twentysix])
    #dot_144 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twentyseven])
    #dot_145 = Dot(normalize = True, axes = -1)([pooling_seven, pooling_twentyeight])
    dot_146 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_nine])
    dot_147 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_ten])
    dot_148 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_eleven])
    dot_149 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twelve])
    dot_150 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_thirteen])
    dot_151 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_fourteen])
    dot_152 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_fifteen])
    dot_153 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_sixteen])
    dot_154 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_seventeen])
    dot_155 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_eighteen])
    dot_156 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_nineteen])
    dot_157 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twenty])
    dot_158 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twentyone])
    #dot_159 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twentytwo])
    #dot_160 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twentythree])
    #dot_161 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twentyfour])
    #dot_162 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twentyfive])
    #dot_163 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twentysix])
    #dot_164 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twentyseven])
    #dot_165 = Dot(normalize = True, axes = -1)([pooling_eight, pooling_twentyeight])
    dot_167 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_ten])
    dot_168 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_eleven])
    dot_169 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twelve])
    dot_170 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_thirteen])
    dot_171 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_fourteen])
    dot_172 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_fifteen])
    dot_173 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_sixteen])
    dot_174 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_seventeen])
    dot_175 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_eighteen])
    dot_176 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_nineteen])
    dot_177 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twenty])
    dot_178 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twentyone])
    #dot_179 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twentytwo])
    #dot_180 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twentythree])
    #dot_181 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twentyfour])
    #dot_182 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twentyfive])
    #dot_183 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twentysix])
    #dot_184 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twentyseven])
    #dot_185 = Dot(normalize = True, axes = -1)([pooling_nine, pooling_twentyeight])
    dot_187 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_eleven])
    dot_188 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twelve])
    dot_189 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_thirteen])
    dot_190 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_fourteen])
    dot_191 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_fifteen])
    dot_192 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_sixteen])
    dot_193 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_seventeen])
    dot_194 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_eighteen])
    dot_195 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_nineteen])
    dot_196 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twenty])
    dot_197 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twentyone])
    #dot_198 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twentytwo])
    #dot_199 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twentythree])
    #dot_200 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twentyfour])
    #dot_201 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twentyfive])
    #dot_202 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twentysix])
    #dot_203 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twentyseven])
    #dot_204 = Dot(normalize = True, axes = -1)([pooling_ten, pooling_twentyeight])
    dot_206 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twelve])
    dot_207 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_thirteen])
    dot_208 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_fourteen])
    dot_209 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_fifteen])
    dot_210 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_sixteen])
    dot_211 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_seventeen])
    dot_212 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_eighteen])
    dot_213 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_nineteen])
    dot_214 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twenty])
    dot_215 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twentyone])
    #dot_216 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twentytwo])
    #dot_217 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twentythree])
    #dot_218 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twentyfour])
    #dot_219 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twentyfive])
    #dot_220 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twentysix])
    #dot_221 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twentyseven])
    #dot_222 = Dot(normalize = True, axes = -1)([pooling_eleven, pooling_twentyeight])   
    dot_224 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_thirteen])
    dot_225 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_fourteen])
    dot_226 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_fifteen])
    dot_227 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_sixteen])
    dot_228 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_seventeen])
    dot_229 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_eighteen])
    dot_230 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_nineteen])
    dot_231 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twenty])
    dot_232 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twentyone])
    #dot_233 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twentytwo])
    #dot_234 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twentythree])
    #dot_235 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twentyfour])
    #dot_236 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twentyfive])
    #dot_237 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twentysix])
    #dot_238 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twentyseven])
    #dot_239 = Dot(normalize = True, axes = -1)([pooling_twelve, pooling_twentyeight])    
    dot_241 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_fourteen])
    dot_242 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_fifteen])
    dot_243 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_sixteen])
    dot_244 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_seventeen])
    dot_245 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_eighteen])
    dot_246 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_nineteen])
    dot_247 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twenty])
    dot_248 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twentyone])
    #dot_249 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twentytwo])
    #dot_250 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twentythree])
    #dot_251 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twentyfour])
    #dot_252 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twentyfive])
    #dot_253 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twentysix])
    #dot_254 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twentyseven])
    #dot_255 = Dot(normalize = True, axes = -1)([pooling_thirteen, pooling_twentyeight]) 
    dot_257 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_fifteen])
    dot_258 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_sixteen])
    dot_259 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_seventeen])
    dot_260 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_eighteen])
    dot_261 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_nineteen])
    dot_262 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twenty])
    dot_263 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twentyone])
    #dot_264 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twentytwo])
    #dot_265 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twentythree])
    #dot_266 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twentyfour])
    #dot_267 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twentyfive])
    #dot_268 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twentysix])
    #dot_269 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twentyseven])
    #dot_270 = Dot(normalize = True, axes = -1)([pooling_fourteen, pooling_twentyeight])
    dot_272 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_sixteen])
    dot_273 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_seventeen])
    dot_274 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_eighteen])
    dot_275 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_nineteen])
    dot_276 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twenty])
    dot_277 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twentyone])
    #dot_278 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twentytwo])
    #dot_279 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twentythree])
    #dot_280 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twentyfour])
    #dot_281 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twentyfive])
    #dot_282 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twentysix])
    #dot_283 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twentyseven])
    #dot_284 = Dot(normalize = True, axes = -1)([pooling_fifteen, pooling_twentyeight])
    dot_286 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_seventeen])
    dot_287 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_eighteen])
    dot_288 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_nineteen])
    dot_289 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twenty])
    dot_290 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twentyone])
    #dot_291 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twentytwo])
    #dot_292 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twentythree])
    #dot_293 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twentyfour])
    #dot_294 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twentyfive])
    #dot_295 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twentysix])
    #dot_296 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twentyseven])
    #dot_297 = Dot(normalize = True, axes = -1)([pooling_sixteen, pooling_twentyeight])
    dot_299 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_eighteen])
    dot_300 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_nineteen])
    dot_301 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twenty])
    dot_302 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twentyone])
    #dot_303 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twentytwo])
    #dot_304 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twentythree])
    #dot_305 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twentyfour])
    #dot_306 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twentyfive])
    #dot_307 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twentysix])
    #dot_308 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twentyseven])
    #dot_309 = Dot(normalize = True, axes = -1)([pooling_seventeen, pooling_twentyeight]) 
    dot_311 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_nineteen])
    dot_312 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twenty])
    dot_313 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twentyone])
    #dot_314 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twentytwo])
    #dot_315 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twentythree])
    #dot_316 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twentyfour])
    #dot_317 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twentyfive])
    #dot_318 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twentysix])
    #dot_319 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twentyseven])
    #dot_320 = Dot(normalize = True, axes = -1)([pooling_eighteen, pooling_twentyeight])
    dot_322 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twenty])
    dot_323 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twentyone])
    #dot_324 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twentytwo])
    #dot_325 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twentythree])
    #dot_326 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twentyfour])
    #dot_327 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twentyfive])
    #dot_328 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twentysix])
    #dot_329 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twentyseven])
    #dot_330 = Dot(normalize = True, axes = -1)([pooling_nineteen, pooling_twentyeight])
    dot_332 = Dot(normalize = True, axes = -1)([pooling_twenty, pooling_twentyone])
    #dot_333 = Dot(normalize = True, axes = -1)([pooling_twenty, pooling_twentytwo])
    #dot_334 = Dot(normalize = True, axes = -1)([pooling_twenty, pooling_twentythree])
    #dot_335 = Dot(normalize = True, axes = -1)([pooling_twenty, pooling_twentyfour])
    #dot_336 = Dot(normalize = True, axes = -1)([pooling_twenty, pooling_twentyfive])
    #dot_337 = Dot(normalize = True, axes = -1)([pooling_twenty, pooling_twentysix])
    #dot_338 = Dot(normalize = True, axes = -1)([pooling_twenty, pooling_twentyseven])
    #dot_339 = Dot(normalize = True, axes = -1)([pooling_twenty, pooling_twentyeight])
    #dot_371 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twentytwo])
    #dot_372 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twentythree])
    #dot_373 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twentyfour])
    #dot_374 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twentyfive])
    #dot_375 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twentysix])
    #dot_376 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twentyseven])
    #dot_377 = Dot(normalize = True, axes = -1)([pooling_five, pooling_twentyeight])
    dot_378 = Dot(normalize = True, axes = -1)([pooling_six, pooling_seven])
    dot_379 = Dot(normalize = True, axes = -1)([pooling_six, pooling_eight])
    dot_380 = Dot(normalize = True, axes = -1)([pooling_six, pooling_nine])
    dot_381 = Dot(normalize = True, axes = -1)([pooling_six, pooling_ten])
    dot_382 = Dot(normalize = True, axes = -1)([pooling_six, pooling_eleven])
    dot_383 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twelve])
    dot_384 = Dot(normalize = True, axes = -1)([pooling_six, pooling_thirteen])
    dot_385 = Dot(normalize = True, axes = -1)([pooling_six, pooling_fourteen])
    dot_386 = Dot(normalize = True, axes = -1)([pooling_six, pooling_fifteen])
    dot_387 = Dot(normalize = True, axes = -1)([pooling_six, pooling_sixteen])
    dot_388 = Dot(normalize = True, axes = -1)([pooling_six, pooling_seventeen])
    dot_389 = Dot(normalize = True, axes = -1)([pooling_six, pooling_eighteen])
    dot_391 = Dot(normalize = True, axes = -1)([pooling_six, pooling_nineteen])
    dot_392 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twenty])
    dot_393 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twentyone])
    #dot_394 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twentytwo])
    #dot_395 = Dot(normalize = True, axes = -1)([pooling_six, pooling_twentythree])
    
    # Interaction gate
    sum_interaction = Add(name = "interaction_gate")([dot_1, dot_2, dot_3, dot_4, dot_5, dot_6, dot_7, dot_8, 
                                                     dot_9, dot_10, dot_11, dot_12, dot_13, dot_14, dot_15, dot_16,
                                                     dot_17, dot_18, dot_19, dot_20, dot_29, dot_30, dot_31, dot_32,
                                                     dot_33, dot_34, dot_35, dot_36, dot_37, dot_38, dot_39, dot_40, 
                                                     dot_41, dot_42, dot_43, dot_44, dot_45, dot_46, dot_54, dot_55, dot_56,
                                                     dot_57, dot_58, dot_59, dot_60, dot_61, dot_62, dot_63, dot_64,
                                                     dot_65, dot_66, dot_67, dot_68, dot_69, dot_70, dot_71, dot_79, dot_80,
                                                     dot_81, dot_82, dot_83, dot_84, dot_85, dot_86, dot_87, dot_88,
                                                     dot_89, dot_90, dot_91, dot_92, dot_93, dot_94, dot_95, dot_103, dot_104,
                                                     dot_105, dot_106, dot_107, dot_108, dot_109, dot_110, dot_111, 
                                                     dot_112, dot_113, dot_114, dot_116, dot_117, dot_118, dot_119,
                                                     dot_125, dot_126, dot_127,
                                                     dot_128, dot_129, dot_130, dot_131, dot_132, dot_133, dot_134, dot_135,
                                                     dot_136, dot_137, dot_138, dot_146, dot_147, dot_148, dot_149, dot_150, dot_151, 
                                                     dot_152, dot_153, dot_154, dot_155, dot_156, dot_157, dot_158, dot_167,
                                                     dot_168, dot_169, dot_170, dot_171, dot_172, dot_173, dot_174, dot_175,
                                                     dot_176, dot_177, dot_178, dot_187, dot_188, dot_189, dot_190, dot_191,
                                                     dot_192, dot_193, dot_194, dot_195, dot_196, dot_197, dot_206, dot_207,
                                                     dot_208, dot_209, dot_210, dot_211, dot_212, dot_213, dot_214, 
                                                     dot_224, dot_225, dot_226, dot_227, dot_228, dot_229, dot_230, dot_231,
                                                     dot_241, dot_242, dot_243, dot_244, dot_245, dot_246, dot_247,
                                                     dot_257, dot_258, dot_259, dot_260, dot_261, dot_262, dot_263,
                                                     dot_272, dot_273, dot_274, dot_275, dot_276, dot_277, dot_286, dot_287,
                                                     dot_288, dot_289, dot_290, dot_299, dot_300, dot_301, dot_302, dot_311,
                                                     dot_312, dot_313, dot_322, dot_323, dot_332, dot_378, dot_379, dot_380, dot_381, dot_382, dot_383,
                                                     dot_384, dot_385, dot_386, dot_387, dot_388, dot_389, dot_391,
                                                     dot_392, dot_393])
                                                    
    
    # Fully connected layer 
    merged = Dense(1, activation = "sigmoid")(sum_interaction)
    model = Model(inputs = [city, country, hotel, rating, 
                           locality, price, landmark], outputs = merged)
    model.compile(optimizer = "Adadelta", loss = "binary_crossentropy", metrics = ["accuracy"])
    
    return model

# Instantiate model and show parameters
model = hotel_embeddings()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# city (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# country (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# hotel (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# rating (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# locality (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# price (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# landmark (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# city_embedding (Embedding)      (None, 1, 50)        103450      city[0][0]
# __________________________________________________________________________________________________
# country_embedding (Embedding)   (None, 1, 50)        6300        country[0][0]
# __________________________________________________________________________________________________
# hotel_embedding (Embedding)     (None, 1, 50)        781400      hotel[0][0]
# __________________________________________________________________________________________________
# rating_embedding (Embedding)    (None, 1, 50)        500         rating[0][0]
# __________________________________________________________________________________________________
# locality_embedding (Embedding)  (None, 1, 50)        307700      locality[0][0]
# __________________________________________________________________________________________________
# price_embedding (Embedding)     (None, 1, 50)        25650       price[0][0]
# __________________________________________________________________________________________________
# landmark_embedding (Embedding)  (None, 1, 50)        760850      landmark[0][0]
# __________________________________________________________________________________________________
# interaction_one (Multiply)      (None, 1, 50)        0           city_embedding[0][0]
#                                                                  country_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_two (Multiply)      (None, 1, 50)        0           city_embedding[0][0]
#                                                                  hotel_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_three (Multiply)    (None, 1, 50)        0           city_embedding[0][0]
#                                                                  rating_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_four (Multiply)     (None, 1, 50)        0           city_embedding[0][0]
#                                                                  locality_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_five (Multiply)     (None, 1, 50)        0           city_embedding[0][0]
#                                                                  price_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_six (Multiply)      (None, 1, 50)        0           city_embedding[0][0]
#                                                                  landmark_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_seven (Multiply)    (None, 1, 50)        0           country_embedding[0][0]
#                                                                  hotel_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_eight (Multiply)    (None, 1, 50)        0           country_embedding[0][0]
#                                                                  rating_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_nine (Multiply)     (None, 1, 50)        0           country_embedding[0][0]
#                                                                  locality_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_ten (Multiply)      (None, 1, 50)        0           country_embedding[0][0]
#                                                                  price_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_eleven (Multiply)   (None, 1, 50)        0           country_embedding[0][0]
#                                                                  landmark_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_twelve (Multiply)   (None, 1, 50)        0           hotel_embedding[0][0]
#                                                                  rating_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_thirteen (Multiply) (None, 1, 50)        0           hotel_embedding[0][0]
#                                                                  locality_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_fourteen (Multiply) (None, 1, 50)        0           hotel_embedding[0][0]
#                                                                  price_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_fifteen (Multiply)  (None, 1, 50)        0           hotel_embedding[0][0]
#                                                                  landmark_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_sixteen (Multiply)  (None, 1, 50)        0           rating_embedding[0][0]
#                                                                  locality_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_seventeen (Multiply (None, 1, 50)        0           rating_embedding[0][0]
#                                                                  price_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_eighteen (Multiply) (None, 1, 50)        0           rating_embedding[0][0]
#                                                                  landmark_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_nineteen (Multiply) (None, 1, 50)        0           locality_embedding[0][0]
#                                                                  price_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_twenty (Multiply)   (None, 1, 50)        0           locality_embedding[0][0]
#                                                                  landmark_embedding[0][0]
# __________________________________________________________________________________________________
# interaction_twentyone (Multiply (None, 1, 50)        0           price_embedding[0][0]
#                                                                  landmark_embedding[0][0]
# __________________________________________________________________________________________________
# pooling_one (GlobalMaxPooling1D (None, 50)           0           interaction_one[0][0]
# __________________________________________________________________________________________________
# pooling_two (GlobalMaxPooling1D (None, 50)           0           interaction_two[0][0]
# __________________________________________________________________________________________________
# pooling_three (GlobalMaxPooling (None, 50)           0           interaction_three[0][0]
# __________________________________________________________________________________________________
# pooling_four (GlobalMaxPooling1 (None, 50)           0           interaction_four[0][0]
# __________________________________________________________________________________________________
# pooling_five (GlobalMaxPooling1 (None, 50)           0           interaction_five[0][0]
# __________________________________________________________________________________________________
# pooling_six (GlobalMaxPooling1D (None, 50)           0           interaction_six[0][0]
# __________________________________________________________________________________________________
# pooling_seven (GlobalMaxPooling (None, 50)           0           interaction_seven[0][0]
# __________________________________________________________________________________________________
# pooling_eight (GlobalMaxPooling (None, 50)           0           interaction_eight[0][0]
# __________________________________________________________________________________________________
# pooling_nine (GlobalMaxPooling1 (None, 50)           0           interaction_nine[0][0]
# __________________________________________________________________________________________________
# pooling_ten (GlobalMaxPooling1D (None, 50)           0           interaction_ten[0][0]
# __________________________________________________________________________________________________
# pooling_eleven (GlobalMaxPoolin (None, 50)           0           interaction_eleven[0][0]
# __________________________________________________________________________________________________
# pooling_twelve (GlobalMaxPoolin (None, 50)           0           interaction_twelve[0][0]
# __________________________________________________________________________________________________
# pooling_thirteen (GlobalMaxPool (None, 50)           0           interaction_thirteen[0][0]
# __________________________________________________________________________________________________
# pooling_fourteen (GlobalMaxPool (None, 50)           0           interaction_fourteen[0][0]
# __________________________________________________________________________________________________
# pooling_fifteen (GlobalMaxPooli (None, 50)           0           interaction_fifteen[0][0]
# __________________________________________________________________________________________________
# pooling_sixteen (GlobalMaxPooli (None, 50)           0           interaction_sixteen[0][0]
# __________________________________________________________________________________________________
# pooling_seventeen (GlobalMaxPoo (None, 50)           0           interaction_seventeen[0][0]
# __________________________________________________________________________________________________
# pooling_eighteen (GlobalMaxPool (None, 50)           0           interaction_eighteen[0][0]
# __________________________________________________________________________________________________
# pooling_nineteen (GlobalMaxPool (None, 50)           0           interaction_nineteen[0][0]
# __________________________________________________________________________________________________
# pooling_twenty (GlobalMaxPoolin (None, 50)           0           interaction_twenty[0][0]
# __________________________________________________________________________________________________
# pooling_twentyone (GlobalMaxPoo (None, 50)           0           interaction_twentyone[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_two[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_three[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_four[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_five[0][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_six[0][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_seven[0][0]
# __________________________________________________________________________________________________
# dot_6 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_eight[0][0]
# __________________________________________________________________________________________________
# dot_7 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_nine[0][0]
# __________________________________________________________________________________________________
# dot_8 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_ten[0][0]
# __________________________________________________________________________________________________
# dot_9 (Dot)                     (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_eleven[0][0]
# __________________________________________________________________________________________________
# dot_10 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_twelve[0][0]
# __________________________________________________________________________________________________
# dot_11 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_thirteen[0][0]
# __________________________________________________________________________________________________
# dot_12 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_fourteen[0][0]
# __________________________________________________________________________________________________
# dot_13 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_fifteen[0][0]
# __________________________________________________________________________________________________
# dot_14 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_sixteen[0][0]
# __________________________________________________________________________________________________
# dot_15 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_seventeen[0][0]
# __________________________________________________________________________________________________
# dot_16 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_eighteen[0][0]
# __________________________________________________________________________________________________
# dot_17 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_nineteen[0][0]
# __________________________________________________________________________________________________
# dot_18 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_twenty[0][0]
# __________________________________________________________________________________________________
# dot_19 (Dot)                    (None, 1)            0           pooling_one[0][0]
#                                                                  pooling_twentyone[0][0]
# __________________________________________________________________________________________________
# dot_21 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_four[0][0]
# __________________________________________________________________________________________________
# dot_22 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_five[0][0]
# __________________________________________________________________________________________________
# dot_23 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_six[0][0]
# __________________________________________________________________________________________________
# dot_24 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_seven[0][0]
# __________________________________________________________________________________________________
# dot_25 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_eight[0][0]
# __________________________________________________________________________________________________
# dot_26 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_nine[0][0]
# __________________________________________________________________________________________________
# dot_27 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_ten[0][0]
# __________________________________________________________________________________________________
# dot_28 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_eleven[0][0]
# __________________________________________________________________________________________________
# dot_29 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_twelve[0][0]
# __________________________________________________________________________________________________
# dot_30 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_thirteen[0][0]
# __________________________________________________________________________________________________
# dot_31 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_fourteen[0][0]
# __________________________________________________________________________________________________
# dot_32 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_fifteen[0][0]
# __________________________________________________________________________________________________
# dot_33 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_sixteen[0][0]
# __________________________________________________________________________________________________
# dot_34 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_seventeen[0][0]
# __________________________________________________________________________________________________
# dot_35 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_eighteen[0][0]
# __________________________________________________________________________________________________
# dot_36 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_nineteen[0][0]
# __________________________________________________________________________________________________
# dot_37 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_twenty[0][0]
# __________________________________________________________________________________________________
# dot_38 (Dot)                    (None, 1)            0           pooling_two[0][0]
#                                                                  pooling_twentyone[0][0]
# __________________________________________________________________________________________________
# dot_39 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_four[0][0]
# __________________________________________________________________________________________________
# dot_40 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_five[0][0]
# __________________________________________________________________________________________________
# dot_41 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_six[0][0]
# __________________________________________________________________________________________________
# dot_42 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_seven[0][0]
# __________________________________________________________________________________________________
# dot_43 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_eight[0][0]
# __________________________________________________________________________________________________
# dot_44 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_nine[0][0]
# __________________________________________________________________________________________________
# dot_45 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_ten[0][0]
# __________________________________________________________________________________________________
# dot_46 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_eleven[0][0]
# __________________________________________________________________________________________________
# dot_47 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_twelve[0][0]
# __________________________________________________________________________________________________
# dot_48 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_thirteen[0][0]
# __________________________________________________________________________________________________
# dot_49 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_fourteen[0][0]
# __________________________________________________________________________________________________
# dot_50 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_fifteen[0][0]
# __________________________________________________________________________________________________
# dot_51 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_sixteen[0][0]
# __________________________________________________________________________________________________
# dot_52 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_seventeen[0][0]
# __________________________________________________________________________________________________
# dot_53 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_eighteen[0][0]
# __________________________________________________________________________________________________
# dot_54 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_nineteen[0][0]
# __________________________________________________________________________________________________
# dot_55 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_twenty[0][0]
# __________________________________________________________________________________________________
# dot_56 (Dot)                    (None, 1)            0           pooling_three[0][0]
#                                                                  pooling_twentyone[0][0]
# __________________________________________________________________________________________________
# dot_57 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_five[0][0]
# __________________________________________________________________________________________________
# dot_58 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_six[0][0]
# __________________________________________________________________________________________________
# dot_59 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_seven[0][0]
# __________________________________________________________________________________________________
# dot_60 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_eight[0][0]
# __________________________________________________________________________________________________
# dot_61 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_nine[0][0]
# __________________________________________________________________________________________________
# dot_62 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_ten[0][0]
# __________________________________________________________________________________________________
# dot_63 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_eleven[0][0]
# __________________________________________________________________________________________________
# dot_64 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_twelve[0][0]
# __________________________________________________________________________________________________
# dot_65 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_thirteen[0][0]
# __________________________________________________________________________________________________
# dot_66 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_fourteen[0][0]
# __________________________________________________________________________________________________
# dot_67 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_fifteen[0][0]
# __________________________________________________________________________________________________
# dot_68 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_sixteen[0][0]
# __________________________________________________________________________________________________
# dot_69 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_seventeen[0][0]
# __________________________________________________________________________________________________
# dot_70 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_eighteen[0][0]
# __________________________________________________________________________________________________
# dot_71 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_nineteen[0][0]
# __________________________________________________________________________________________________
# dot_72 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_twenty[0][0]
# __________________________________________________________________________________________________
# dot_73 (Dot)                    (None, 1)            0           pooling_four[0][0]
#                                                                  pooling_twentyone[0][0]
# __________________________________________________________________________________________________
# dot_74 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_six[0][0]
# __________________________________________________________________________________________________
# dot_75 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_seven[0][0]
# __________________________________________________________________________________________________
# dot_76 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_eight[0][0]
# __________________________________________________________________________________________________
# dot_77 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_nine[0][0]
# __________________________________________________________________________________________________
# dot_78 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_ten[0][0]
# __________________________________________________________________________________________________
# dot_79 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_eleven[0][0]
# __________________________________________________________________________________________________
# dot_80 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_twelve[0][0]
# __________________________________________________________________________________________________
# dot_81 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_thirteen[0][0]
# __________________________________________________________________________________________________
# dot_82 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_fourteen[0][0]
# __________________________________________________________________________________________________
# dot_83 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_fifteen[0][0]
# __________________________________________________________________________________________________
# dot_84 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_sixteen[0][0]
# __________________________________________________________________________________________________
# dot_85 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_seventeen[0][0]
# __________________________________________________________________________________________________
# dot_86 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_eighteen[0][0]
# __________________________________________________________________________________________________
# dot_87 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_nineteen[0][0]
# __________________________________________________________________________________________________
# dot_88 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_twenty[0][0]
# __________________________________________________________________________________________________
# dot_89 (Dot)                    (None, 1)            0           pooling_five[0][0]
#                                                                  pooling_twentyone[0][0]
# __________________________________________________________________________________________________
# dot_90 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_eight[0][0]
# __________________________________________________________________________________________________
# dot_91 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_nine[0][0]
# __________________________________________________________________________________________________
# dot_92 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_ten[0][0]
# __________________________________________________________________________________________________
# dot_93 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_eleven[0][0]
# __________________________________________________________________________________________________
# dot_94 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_twelve[0][0]
# __________________________________________________________________________________________________
# dot_95 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_thirteen[0][0]
# __________________________________________________________________________________________________
# dot_96 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_fourteen[0][0]
# __________________________________________________________________________________________________
# dot_97 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_fifteen[0][0]
# __________________________________________________________________________________________________
# dot_98 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_sixteen[0][0]
# __________________________________________________________________________________________________
# dot_99 (Dot)                    (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_seventeen[0][0]
# __________________________________________________________________________________________________
# dot_100 (Dot)                   (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_eighteen[0][0]
# __________________________________________________________________________________________________
# dot_101 (Dot)                   (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_nineteen[0][0]
# __________________________________________________________________________________________________
# dot_102 (Dot)                   (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_twenty[0][0]
# __________________________________________________________________________________________________
# dot_103 (Dot)                   (None, 1)            0           pooling_seven[0][0]
#                                                                  pooling_twentyone[0][0]
# __________________________________________________________________________________________________
# dot_104 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_nine[0][0]
# __________________________________________________________________________________________________
# dot_105 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_ten[0][0]
# __________________________________________________________________________________________________
# dot_106 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_eleven[0][0]
# __________________________________________________________________________________________________
# dot_107 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_twelve[0][0]
# __________________________________________________________________________________________________
# dot_108 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_thirteen[0][0]
# __________________________________________________________________________________________________
# dot_109 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_fourteen[0][0]
# __________________________________________________________________________________________________
# dot_110 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_fifteen[0][0]
# __________________________________________________________________________________________________
# dot_111 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_sixteen[0][0]
# __________________________________________________________________________________________________
# dot_112 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_seventeen[0][0]
# __________________________________________________________________________________________________
# dot_113 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_eighteen[0][0]
# __________________________________________________________________________________________________
# dot_114 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_nineteen[0][0]
# __________________________________________________________________________________________________
# dot_115 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_twenty[0][0]
# __________________________________________________________________________________________________
# dot_116 (Dot)                   (None, 1)            0           pooling_eight[0][0]
#                                                                  pooling_twentyone[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  dot_51[0][0]
#                                                                  dot_52[0][0]
#                                                                  dot_53[0][0]
#                                                                  dot_54[0][0]
#                                                                  dot_55[0][0]
#                                                                  dot_56[0][0]
#                                                                  dot_57[0][0]
#                                                                  dot_58[0][0]
#                                                                  dot_59[0][0]
#                                                                  dot_60[0][0]
#                                                                  dot_61[0][0]
#                                                                  dot_62[0][0]
#                                                                  dot_63[0][0]
#                                                                  dot_64[0][0]
#                                                                  dot_65[0][0]
#                                                                  dot_66[0][0]
#                                                                  dot_67[0][0]
#                                                                  dot_68[0][0]
#                                                                  dot_69[0][0]
#                                                                  dot_70[0][0]
#                                                                  dot_71[0][0]
#                                                                  dot_72[0][0]
#                                                                  dot_73[0][0]
#                                                                  dot_74[0][0]
#                                                                  dot_75[0][0]
#                                                                  dot_76[0][0]
#                                                                  dot_77[0][0]
#                                                                  dot_78[0][0]
#                                                                  dot_79[0][0]
#                                                                  dot_80[0][0]
#                                                                  dot_81[0][0]
#                                                                  dot_82[0][0]
#                                                                  dot_83[0][0]
#                                                                  dot_84[0][0]
#                                                                  dot_85[0][0]
#                                                                  dot_86[0][0]
#                                                                  dot_87[0][0]
#                                                                  dot_88[0][0]
#                                                                  dot_89[0][0]
#                                                                  dot_90[0][0]
#                                                                  dot_91[0][0]
#                                                                  dot_92[0][0]
#                                                                  dot_93[0][0]
#                                                                  dot_94[0][0]
#                                                                  dot_95[0][0]
#                                                                  dot_96[0][0]
#                                                                  dot_97[0][0]
#                                                                  dot_98[0][0]
#                                                                  dot_99[0][0]
#                                                                  dot_100[0][0]
#                                                                  dot_101[0][0]
#                                                                  dot_102[0][0]
#                                                                  dot_103[0][0]
#                                                                  dot_104[0][0]
#                                                                  dot_105[0][0]
#                                                                  dot_106[0][0]
#                                                                  dot_107[0][0]
#                                                                  dot_108[0][0]
#                                                                  dot_109[0][0]
#                                                                  dot_110[0][0]
#                                                                  dot_111[0][0]
#                                                                  dot_112[0][0]
#                                                                  dot_113[0][0]
#                                                                  dot_114[0][0]
#                                                                  dot_115[0][0]
#                                                                  dot_116[0][0]
#                                                                  dot_117[0][0]
#                                                                  dot_118[0][0]
#                                                                  dot_119[0][0]
#                                                                  dot_120[0][0]
#                                                                  dot_121[0][0]
#                                                                  dot_122[0][0]
#                                                                  dot_123[0][0]
#                                                                  dot_124[0][0]
#                                                                  dot_125[0][0]
#                                                                  dot_126[0][0]
#                                                                  dot_127[0][0]
#                                                                  dot_128[0][0]
#                                                                  dot_129[0][0]
#                                                                  dot_130[0][0]
#                                                                  dot_131[0][0]
#                                                                  dot_132[0][0]
#                                                                  dot_133[0][0]
#                                                                  dot_134[0][0]
#                                                                  dot_135[0][0]
#                                                                  dot_136[0][0]
#                                                                  dot_137[0][0]
#                                                                  dot_138[0][0]
#                                                                  dot_139[0][0]
#                                                                  dot_140[0][0]
#                                                                  dot_141[0][0]
#                                                                  dot_142[0][0]
#                                                                  dot_143[0][0]
#                                                                  dot_144[0][0]
#                                                                  dot_145[0][0]
#                                                                  dot_146[0][0]
#                                                                  dot_147[0][0]
#                                                                  dot_148[0][0]
#                                                                  dot_150[0][0]
#                                                                  dot_151[0][0]
#                                                                  dot_152[0][0]
#                                                                  dot_153[0][0]
#                                                                  dot_154[0][0]
#                                                                  dot_155[0][0]
#                                                                  dot_156[0][0]
#                                                                  dot_157[0][0]
#                                                                  dot_159[0][0]
#                                                                  dot_160[0][0]
#                                                                  dot_161[0][0]
#                                                                  dot_162[0][0]
#                                                                  dot_163[0][0]
#                                                                  dot_164[0][0]
#                                                                  dot_165[0][0]
#                                                                  dot_167[0][0]
#                                                                  dot_168[0][0]
#                                                                  dot_169[0][0]
#                                                                  dot_170[0][0]
#                                                                  dot_171[0][0]
#                                                                  dot_172[0][0]
#                                                                  dot_173[0][0]
#                                                                  dot_174[0][0]
#                                                                  dot_175[0][0]
#                                                                  dot_176[0][0]
#                                                                  dot_177[0][0]
#                                                                  dot_178[0][0]
#                                                                  dot_179[0][0]
#                                                                  dot_180[0][0]
#                                                                  dot_181[0][0]
#                                                                  dot_182[0][0]
#                                                                  dot_183[0][0]
#                                                                  dot_184[0][0]
#                                                                  dot_185[0][0]
#                                                                  dot_186[0][0]
#                                                                  dot_187[0][0]
#                                                                  dot_188[0][0]
#                                                                  dot_189[0][0]
#                                                                  dot_190[0][0]
#                                                                  dot_191[0][0]
#                                                                  dot_192[0][0]
#                                                                  dot_193[0][0]
#                                                                  dot_194[0][0]
#                                                                  dot_195[0][0]
#                                                                  dot_196[0][0]
#                                                                  dot_197[0][0]
#                                                                  dot_198[0][0]
#                                                                  dot_199[0][0]
#                                                                  dot_200[0][0]
#                                                                  dot_201[0][0]
#                                                                  dot_202[0][0]
#                                                                  dot_203[0][0]
#                                                                  dot_204[0][0]
#                                                                  dot_205[0][0]
#                                                                  dot_206[0][0]
#                                                                  dot_207[0][0]
#                                                                  dot_208[0][0]
#                                                                  dot_209[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            2           interaction_gate[0][0]
# ==================================================================================================
# Total params: 1,985,852
# Trainable params: 1,985,852
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train Model

n_positive = 2000

# Create generator 
generator = generate_batch(hotel_tuples, n_positive, negative_ratio = 1)

# Train

item_property = model.fit_generator(generator, epochs = 100,
                        steps_per_epoch = len(hotel_tuples) // n_positive, verbose = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/2236270496.py in <module>
#       4
#       5 # Create generator
# ----> 6 generator = generate_batch(hotel_tuples, n_positive, negative_ratio = 1)
#       7
#       8 # Train
#
# NameError: name 'hotel_tuples' is not defined

# %%
# Save model
model.save("embeddings_v2.h5")
model.save_weights("embeddings_v2_weights.h5")
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
# Import embeddings model and weights
embeddings_model = models.load_model("../input/hotelsitems/embeddings_v2.h5")
embeddings_model.load_weights("../input/hotelsitems/embeddings_v2_weights.h5")

# %%
# Extract embeddings
city_layer = embeddings_model.get_layer("city_embedding")
city_weights = city_layer.get_weights()[0]
country_layer = embeddings_model.get_layer("country_embedding")
country_weights = country_layer.get_weights()[0]
hotel_layer = embeddings_model.get_layer("hotel_embedding")
hotel_weights = hotel_layer.get_weights()[0]
rating_layer = embeddings_model.get_layer("rating_embedding")
rating_weights = rating_layer.get_weights()[0]
locality_layer = embeddings_model.get_layer("locality_embedding")
locality_weights = locality_layer.get_weights()[0]
price_layer = embeddings_model.get_layer("price_embedding")
price_weights = price_layer.get_weights()[0]
landmark_layer = embeddings_model.get_layer("landmark_embedding")
landmark_weights = landmark_layer.get_weights()[0]

# Normalize the embeddings so that we can calculate cosine similarity
city_weights = city_weights / np.linalg.norm(city_weights, axis = 1).reshape((-1, 1))
country_weights = country_weights / np.linalg.norm(country_weights, axis = 1).reshape((-1, 1))
hotel_weights = hotel_weights / np.linalg.norm(hotel_weights, axis = 1).reshape((-1, 1))
rating_weights = rating_weights / np.linalg.norm(rating_weights, axis =1 ).reshape((-1, 1))
locality_weights = locality_weights / np.linalg.norm(locality_weights, axis =1 ).reshape((-1, 1))
price_weights = price_weights / np.linalg.norm(price_weights, axis =1 ).reshape((-1, 1))
landmark_weights = landmark_weights / np.linalg.norm(landmark_weights, axis =1 ).reshape((-1, 1))

# %%
distances = np.dot(hotel_weights, hotel_weights[hotel_index["relax apartment"]])

# %%
# Finding similar hotels
def find_similar_hotels(name, weights, index_name = "hotel_name", n = 20, 
                        return_dist = False, filtering = False, filter_name = None):
    
    # Select index and reverse index
    if index_name == "city":
        index = city_index
        rindex = index_city
    if index_name == "country":
        index = country_index
        rindex = index_country
    if index_name == "hotel_name":
        index = hotel_index
        rindex = index_hotel
    if index_name == "rating":
        index = rating_index
        rindex = index_rating
    if index_name == "locality":
        index = locality_index
        rindex = index_locality
    if index_name == "price":
        index = price_index
        rindex = index_price
    if index_name == "landmark":
        index = landmark_index
        rindex = index_landmark
    
    # Check name is in index
    try:
        # Calculate dot product between item/property and all others
        distances = np.dot(weights, weights[index[name]])
    except KeyError:
        print(" {} Not Found.".format(name))
        return
    
    # Sort distances from smallest to largest
    sorted_distances = np.argsort(distances)
        
    # Find the most similar
    closest = sorted_distances[-n:-1]
    
    # Limit results by filtering
    filter_ = None
    filtered_results = []
    results_dict = {}
    if filtering:
        for idxs, rows in hotels_df.iterrows():
            if hotels_df.at[idxs, index_name] == name:
                filter_ = hotels_df.at[idxs, filter_name]
                break
        match_df = hotels_df[hotels_df[filter_name].str.match(filter_)]
        match_df = match_df.reset_index(drop = True)
        match_df["distance"] = None
        for idxs, rows in match_df.iterrows():
            item = match_df.at[idxs, index_name]
            distance = np.dot(weights[index[item]], weights[index[name]])
            match_df.loc[match_df.index[idxs], "distance"] = distance
        match_df = match_df.sort_values(by = ["distance"], axis = 0, ascending = False)
        results_dict = match_df.to_dict(orient = "list")
        list_of_filtered_results = match_df[index_name].to_list()
        for item in list_of_filtered_results:
            if item not in filtered_results:
                filtered_results.append(item)   
        return filtered_results
                
                    
    # If return_dist True
    if return_dist:
        return distances, closest
    
    # Print the most similar and distances
    for c in reversed(closest):
        print("{}: {} Similarity: {}".format(index_name.capitalize(), rindex[c], distances[c], 2))

# %%
find_similar_hotels("rheincity hotel", hotel_weights, n = 15, filter_name = "hotel_name")
# Out:
# Hotel_name: ocean forest 2003 Similarity: 0.5720937848091125
# Hotel_name: nontiscordardimè Similarity: 0.5236750245094299
# Hotel_name: law courts hotel Similarity: 0.5006973743438721
# Hotel_name: i giardini di athena – athena resort Similarity: 0.4869675636291504
# Hotel_name: hotel pas de calais Similarity: 0.47088736295700073
# Hotel_name: val de ruda luxe 28 by feelfree rentals Similarity: 0.4695252776145935
# Hotel_name: grand hotel london Similarity: 0.4628971815109253
# Hotel_name: san francisco hotel monumento Similarity: 0.4627121388912201
# Hotel_name: apartamento san vicente ferrer Similarity: 0.453341007232666
# Hotel_name: solaz del moros Similarity: 0.45006421208381653
# Hotel_name: kf deluxe b&b Similarity: 0.448048859834671
# Hotel_name: san martin cataratas resort & spa Similarity: 0.4467920958995819
# Hotel_name: durban house kettering Similarity: 0.4456321895122528
# Hotel_name: hotel montebello Similarity: 0.4350750744342804

# %%
hotel_index
# Out:
# {'cozy kunsthaus graz': 0,
#  'hotel hirsch': 1,
#  'h+ hotel nürnberg': 2,
#  'bjäre golfklubb hotel & lodge': 3,
#  'casa telmo': 4,
#  'rnb bhopal': 5,
#  'wiki hostels': 6,
#  'i boschetti': 7,
#  'casa violetta - bed & breakfast': 8,
#  'albany guest house': 9,
#  'wolf creek resort': 10,
#  'hotel u branky': 11,
#  'central comfy apartment': 12,
#  'aibonito hotel 207': 13,
#  'spapparra b&b': 14,
#  'holiday inn express & suites duluth north - miller hill': 15,
#  'inn at morro bay': 16,
#  'the augustin': 17,
#  'hermes hotel': 18,
#  "residenza d'epoca montanini": 19,
#  'the homeboat company piccola - cagliari': 20,
#  'la demeure des tilleuls': 21,
#  'silver legacy resort casino at the row': 22,
#  'die schlafstube 2.0': 23,
#  'econo lodge': 24,
#  'casa orsu maria': 25,
#  'hotel ferrari': 26,
#  'hotel as américas': 27,
#  "trotula charming house - olimpia's flat": 28,
#  'herberg boswijck': 29,
#  "chambres d'hôtes joly saint sauveur": 30,
#  'la croix de savoie & spa': 31,
#  'jindy inn': 32,
#  'hotelo kathedral antwerp': 33,
#  'chalet d anse reunion': 34,
#  'hotel restaurant elite visp': 35,
#  '2 bedroom apartment in dafinka guest house': 36,
#  'hotel venta baños': 37,
#  'zen rooms leonard wood rd baguio': 38,
#  'the gloria suites jakarta': 39,
#  'un petit paradis': 40,
#  'piazza heritage hotel': 41,
#  'imeretinskiy hotel': 42,
#  'château de peufeilhoux': 43,
#  'arthaushotel': 44,
#  'nandika residency hotel': 45,
#  'onkel resort hotel - all inclusive': 46,
#  'camping & pension au an der donau': 47,
#  'apartments by nevsky forum hotel': 48,
#  'belltown court loft penthouse - one bedroom apartment with balcony': 49,
#  'lilians city center studio': 50,
#  'sonder - bayou on the bend': 51,
#  'alpha-palmiers hotel by fassbind': 52,
#  'hotel route-inn shibukawa': 53,
#  'playa suites': 54,
#  'catalonia berlin mitte': 55,
#  'the finchs arms': 56,
#  'relais il margarito': 57,
#  'vongdeuan resort': 58,
#  "maison d'hôtes la bihorée": 59,
#  'bungalows cordial sandy golf': 60,
#  "chambres d'hôtes confortables": 61,
#  'hotel san diego': 62,
#  'b&b casa tomà': 63,
#  'host & home': 64,
#  'popolo & flaminio rooms': 65,
#  'hotel aldea del bazar': 66,
#  'holiday inn express & suites ithaca': 67,
#  'hotel grand teguise playa': 68,
#  'sungarden wellness & conference hotel': 69,
#  'raas jodhpur': 70,
#  'hotel-restaurant de la poste': 71,
#  'rydges sydney airport hotel': 72,
#  'apartement center of paris': 73,
#  'hotel & spa riviera castelsardo': 74,
#  'matina pefkos aparthotel': 75,
#  'mas de martinet': 76,
#  'bergamo inn 43': 77,
#  'b59 hotel': 78,
#  "jimmy's apartments": 79,
#  'les manoirs des portes de deauville': 80,
#  'vlissingen b&b': 81,
#  'hotel new ocean paradise': 82,
#  'ana crowne plaza niigata': 83,
#  'turmhotel zum erasmus': 84,
#  'radisson blu resort & congress centre, sochi': 85,
#  'executive inn and suites': 86,
#  'kennacoil': 87,
#  "bianca's house hotel heathrow airport": 88,
#  'yearling restaurant and cabins': 89,
#  'mein heim estate': 90,
#  'pousada montemar': 91,
#  'icaraí praia hotel': 92,
#  'pension - restaurant sabato': 93,
#  'bahama breeze beach apartment b&b': 94,
#  'altinersan hotel': 95,
#  'avignon grand hotel': 96,
#  'the ceo duplex soho suite': 97,
#  'la posada beach walking studio': 98,
#  'yangshuo mountain retreat': 99,
#  'pousada do morro verde': 100,
#  'robinson club kyllini beach': 101,
#  'la casa': 102,
#  'borgo del belanasc - case vacanza': 103,
#  'youth hostel sion': 104,
#  'residence bartolini ai campi da golf': 105,
#  'hotel polo max jabalpur': 106,
#  'agriturismo el crear': 107,
#  'club torre vella': 108,
#  'real inn ciudad juárez': 109,
#  'mercure rouen centre cathedrale': 110,
#  'hotel carmin': 111,
#  'bristol jangada fortaleza hotel': 112,
#  'serhs natal grand hotel & resort': 113,
#  'comfort hotel tendo': 114,
#  'the only pine apartments': 115,
#  'hotel schwibbogen': 116,
#  'kasa san mateo apartments': 117,
#  'hotel route-inn dai-ni suwa inter': 118,
#  'adis hotels ibadan': 119,
#  'barclay heights b&b at smythe house': 120,
#  'milord hotel boutique': 121,
#  'milestay - paris montmartre': 122,
#  'design flats botanico': 123,
#  'hotel naturmed carbona': 124,
#  'taj hari mahal jodhpur': 125,
#  'wheal hart': 126,
#  'hilton hua hin resort & spa': 127,
#  'the gower golf club': 128,
#  'hotel golte': 129,
#  "residhotel les hauts d'andilly": 130,
#  'super 8 by wyndham cabot': 131,
#  'sea & city apartment in voula': 132,
#  'the garrison': 133,
#  'hotel ramada': 134,
#  'summit hampton hotel': 135,
#  'bamboo bed & breakfast': 136,
#  'hotel schaepkens van st fijt': 137,
#  'parador de jávea': 138,
#  'president hotel mito': 139,
#  'seegarten swiss quality hotel': 140,
#  'beautiful apartment': 141,
#  'savoy hotel': 142,
#  'apartment zuvan': 143,
#  'apartment eindhoven centre': 144,
#  'hotel cartesiano puebla': 145,
#  'len & leona holiday hideout': 146,
#  'ktm resort': 147,
#  'signal rock glencoe cottages': 148,
#  'hosteria san benito': 149,
#  'schlossgut gross schwansee': 150,
#  "chateau d'angkor la residence": 151,
#  'howard johnson riverfront plaza fuzhou': 152,
#  'san carlo suite': 153,
#  'karaku inn': 154,
#  'b&b il sambuco': 155,
#  'hôtel r. kipling by happyculture': 156,
#  'cruz con mar luxury apartments by ha': 157,
#  'romantik hotel stern': 158,
#  'hotel san lorenzo boutique': 159,
#  'le taconet': 160,
#  'novum hotel bremer haus bremen': 161,
#  'zanzibar serena hotel': 162,
#  'hotel alpenrose': 163,
#  'hotel misión y spa acapulco': 164,
#  'landhotel & reiterhof schumann e.k.': 165,
#  'relais du village': 166,
#  'villa il castagno wine & resort': 167,
#  'aventura hotel': 168,
#  'holiday club puerto calma': 169,
#  'la cappella hotel': 170,
#  'dubas apartments': 171,
#  'art boutique hotel': 172,
#  'h10 london waterloo': 173,
#  'chayadol resort': 174,
#  'bijoux de rome apartment vatican': 175,
#  'hotel flora parc': 176,
#  'continental palace': 177,
#  'château de drudas': 178,
#  'azalea apartments': 179,
#  'hotel city': 180,
#  'the plaza tirana': 181,
#  'adirondack spruce lodge': 182,
#  'elegant arno view': 183,
#  'dolphin shores': 184,
#  'helios legend hotel': 185,
#  'motel ranč': 186,
#  'harper perintis - makassar': 187,
#  'villa vergueiro hotel': 188,
#  'hotel snezhanka': 189,
#  'rainbow takayama private house': 190,
#  'grand mirage resort & thalasso bali': 191,
#  'ayodya resort bali': 192,
#  '4br brent road ross anne transient': 193,
#  'abinea dolomiti romantic spa hotel': 194,
#  'diego de almagro calama express': 195,
#  "hotel ilaria & residenza dell'alba": 196,
#  'villa favola': 197,
#  'ellerbeck mansion bed & breakfast - world traveler room.': 198,
#  'secrets the vine cancun - all inclusive - adults only': 199,
#  'radisson blu hotel zurich airport': 200,
#  'villa la estancia beach resort & spa riviera nayarit': 201,
#  'marktschänke': 202,
#  's hotel': 203,
#  'roter ochsen': 204,
#  'hotel delamar - adults only': 205,
#  'kos bay hotel': 206,
#  'winter garden hotel - bergamo airport': 207,
#  'sensi paradise beach resort': 208,
#  'heritance tea factory': 209,
#  'wohlfuehlhotel schiestl': 210,
#  'villa gallistl': 211,
#  'hotel palmensis': 212,
#  'berlin grande hotel': 213,
#  'aibonito hotel 203': 214,
#  'cleopatra classic hotel': 215,
#  'hotel rosenvilla': 216,
#  'la quinta inn & suites by wyndham searcy': 217,
#  'private beach and pool house': 218,
#  'youth hostel gstaad saanenland': 219,
#  'hotel granada johor bahru': 220,
#  'focus motel and executive suites': 221,
#  'riviera hotel': 222,
#  'the sunbeam hideaway bed & breakfast': 223,
#  'the garden cottage guest house': 224,
#  'astoria park hotel spa resort': 225,
#  'best western plus city centre hotel den bosch': 226,
#  'west beach lagoon 114': 227,
#  'hotel moya': 228,
#  'dotter 17': 229,
#  'signoria': 230,
#  'hotel concorde': 231,
#  'hotel rina sinaia': 232,
#  'arbor house suites bed and breakfast': 233,
#  'marion motor lodge': 234,
#  'ace hôtel brive-la-gaillarde': 235,
#  'haus seestern': 236,
#  'la vagabonde': 237,
#  "chambres d'hôtes les côtes d'armor": 238,
#  'auberge de mon petit chum b&b': 239,
#  'ocean melodies 10b - 2 br condo': 240,
#  'the blue anchor': 241,
#  'muthu newton hotel': 242,
#  'eberle': 243,
#  'ilgaz hotel': 244,
#  'hotel kino': 245,
#  'heritage inn picayune': 246,
#  'hyde park guest house': 247,
#  'villa di capovento': 248,
#  "hyena's call": 249,
#  'golden legend diamond hotel': 250,
#  'la sapiniére': 251,
#  'hermanus beachfront lodge': 252,
#  'hotel fortuna': 253,
#  'hotel schloss weikersdorf': 254,
#  'upper apart': 255,
#  'louis hostel': 256,
#  'silvana 132 studio': 257,
#  "robbie's place tobago": 258,
#  'hotel rodebachmühle': 259,
#  'the landmark hotel': 260,
#  'boardinghotel heidelberg': 261,
#  'hotel city center': 262,
#  'cosmopolitan suites': 263,
#  'country inn & suites by radisson, charleston north, sc': 264,
#  'finca victoria': 265,
#  'appartamenti le terme': 266,
#  'netlada resort': 267,
#  'residence regina elena': 268,
#  'akena relais bordeaux sud la brède': 269,
#  'hotel blanca de navarra': 270,
#  'wellton riverside spa hotel': 271,
#  'hotel conrad': 272,
#  'kovalam beach hotel': 273,
#  'mintrops land hotel burgaltendorf': 274,
#  'panoramahotel am rosengarten': 275,
#  'salobre hotel resort & serenity': 276,
#  'culliss house': 277,
#  'house with 4 bedrooms in mouterre-silly, with pool access, enclosed garden and wifi - 180 km from the beach': 278,
#  'maison nô': 279,
#  'albala house unit 0962 3 bedrooms 3.5 bathrooms home': 280,
#  'geroldswil swiss quality hotel': 281,
#  'shelter hotel los angeles': 282,
#  'leonardo boutique hotel rigihof zurich': 283,
#  'borgo dei conti resort': 284,
#  'historic torun central rooms': 285,
#  'bergresort seefeld': 286,
#  'palm leaf resort': 287,
#  "le glam's hôtel": 288,
#  'levanta luxury stone villa': 289,
#  "appart'hôtel le colombier": 290,
#  'h10 corregidor boutique hotel': 291,
#  'canadian village goryu': 292,
#  'dolomiti village': 293,
#  'hotel 525': 294,
#  'villa des ursulines': 295,
#  'hassler roma': 296,
#  'funda hotel': 297,
#  'hotel zum alten fährhaus': 298,
#  'the house': 299,
#  'apartment tilda': 300,
#  'acta antibes': 301,
#  'aparthotel cabau aquasol': 302,
#  'peppers soul surfers paradise': 303,
#  "pipa's bay": 304,
#  'horizon b and b': 305,
#  'cosmopolite': 306,
#  'skaneateles suites boutique hotel': 307,
#  'relais frattina': 308,
#  'sol house the studio calviá beach': 309,
#  'mariandy hotel': 310,
#  'hotel de la bourse': 311,
#  'hotel don miguel': 312,
#  'somerset victoria park hong kong': 313,
#  'grand residences riviera cancun': 314,
#  'return to me 45c - 2 br condo': 315,
#  '6 varis apartments': 316,
#  'boutique-hotel adara': 317,
#  'grand colonial bed and breakfast': 318,
#  'my forte relais de charme': 319,
#  'hotel misiana': 320,
#  'grand hotel brasov': 321,
#  'pousada canto do mares': 322,
#  'the royal sands & spa all inclusive': 323,
#  'billings hotel and convention center': 324,
#  'la quinta #161 - 3 br condo': 325,
#  'art apartment ognissanti': 326,
#  'cn2i luxury accommodation center bv': 327,
#  'puralã - wool valley hotel & spa': 328,
#  'hanmer springs scenic views motel': 329,
#  'jack castle': 330,
#  'hotel růže': 331,
#  'hôtel chambellan morgane': 332,
#  'hotel saline palinuro': 333,
#  'rame barton': 334,
#  'altera hotel im herbartgang': 335,
#  'kasa seattle bellevue apartments': 336,
#  'penzion zivka': 337,
#  'yadis ibn khaldoun': 338,
#  'la vie en rose appartement': 339,
#  'london extended stay': 340,
#  'high country lodge': 341,
#  'diego de almagro valdivia hotel': 342,
#  'me london': 343,
#  'the chill out hostel': 344,
#  'anantara bophut koh samui resort': 345,
#  'omiya ryokan': 346,
#  'haus ares': 347,
#  'peters hotel & spa': 348,
#  "algila' ortigia charme hotel": 349,
#  'misty waves boutique hotel': 350,
#  'reef backpackers': 351,
#  'gutenberg studio deluxe': 352,
#  'locanda osteria marascia': 353,
#  'quinemant lodge': 354,
#  'la clé des champs': 355,
#  'domaine gille': 356,
#  'hamadryade lodge': 357,
#  'stadthotel freilassing': 358,
#  'the cove of lake geneva': 359,
#  "captain's cove 304 - 2 br condo by redawning": 360,
#  "ruchti's hotel und restaurant": 361,
#  "hotel leon d'oro": 362,
#  'dusit princess chiang mai': 363,
#  'riessersee hotel': 364,
#  'home2 suites by hilton statesboro': 365,
#  'ras village': 366,
#  'mountain top ranch - three bedroom house': 367,
#  'casa rural el portillo': 368,
#  'hotel conde luna': 369,
#  '3b beauty bed and breakfast': 370,
#  'residenza ave roma': 371,
#  'hotel land gut höhne': 372,
#  'villa gypsy hotel': 373,
#  'cite hotel': 374,
#  'melody maker cancun - all inclusive': 375,
#  'the edgerley suites': 376,
#  'hotel berna': 377,
#  'willa marcella': 378,
#  'waterside boutique hotel': 379,
#  'hotel posada spa antigua casa hogar': 380,
#  'ravindra beach resort and spa': 381,
#  "chambres d'hôtes residence de vaux": 382,
#  'casa rural abuela simona': 383,
#  'borgo condé wine resort': 384,
#  'yellow wood hous': 385,
#  'coco ocean resort & spa': 386,
#  "les chambres d'hôtes du mas de l'amarine": 387,
#  'hotel crown hills koriyama': 388,
#  'the norwalk inn & conference center': 389,
#  'hoposa pollentia - adults only': 390,
#  'idyllwild bunkhouse': 391,
#  'eastern and oriental hotel': 392,
#  'jilin songyuan hotel': 393,
#  'takinoyu hotel': 394,
#  'domux home ricasoli': 395,
#  'avoca house': 396,
#  'arcona living schaffhausen': 397,
#  'böda hotell': 398,
#  'pheasant run resort': 399,
#  'room 4 apartments': 400,
#  'country inn & suites by radisson, new braunfels, tx': 401,
#  'luxury rooms floramye - adults only': 402,
#  'peartree lodge waterside': 403,
#  'leone': 404,
#  'herisau swiss quality hotel': 405,
#  'rose park hotel al barsha': 406,
#  'château de castelneau': 407,
#  'cyprus villages': 408,
#  'casa marinella': 409,
#  'locanda delle storie': 410,
#  'hotel sfera': 411,
#  'geotel calama': 412,
#  'concorde old bucharest hotel': 413,
#  'alster waterfront city apartments': 414,
#  'ascot guest house': 415,
#  "motel de l'anse à l'eau": 416,
#  'cretan dream royal hotel': 417,
#  'catalonia puerta del sol': 418,
#  'hotel 87 eighty-seven': 419,
#  'hallwil swiss quality seehotel': 420,
#  'sa cottilla': 421,
#  'by the sea': 422,
#  'b&b in centro': 423,
#  'ellerbeck mansion bed & breakfast - calm seas room.': 424,
#  'b&b la margine': 425,
#  'konventum konferencecenter': 426,
#  'opera hostel': 427,
#  'agrumare farm holiday': 428,
#  'hotel gilleleje strand': 429,
#  'house located in a rustic environment just outside the centre of wuppertal': 430,
#  'city apartments eilat': 431,
#  'casale lucrezia': 432,
#  'balneario de archena - hotel levante': 433,
#  'hotel gran ultonia': 434,
#  'the inn at ocean grove': 435,
#  'woodside lodge': 436,
#  'le champ bouchon': 437,
#  'lynnhurst family resort': 438,
#  'cozy apartments': 439,
#  'youth hostel schaffhausen': 440,
#  'kärnten appartements': 441,
#  'plumbohms echt-harz-apartments': 442,
#  'b&b kasteel nijswiller': 443,
#  'hotel lunetta': 444,
#  'super 8 by wyndham macomb': 445,
#  'hotel am hopfensee': 446,
#  'active resorts urabandai': 447,
#  'mood beach hotel': 448,
#  'hotel schatzmann': 449,
#  'brick design hotel': 450,
#  'windward apartments': 451,
#  "antica locanda dell'orso": 452,
#  'hampton by hilton swinoujscie': 453,
#  'hotel solverde spa & wellness center': 454,
#  'bc apartments': 455,
#  'santa barbara hotel': 456,
#  "l' eroico": 457,
#  'serhs villas da pipa hotel': 458,
#  'palazzo del carretto': 459,
#  'kunst hotel zur post': 460,
#  'sigiriya nature villa lodge': 461,
#  'landhotel schönberghof & gästehaus enzinger': 462,
#  'vivaldi luxury rooms': 463,
#  'maritim berghotel braunlage': 464,
#  'ibis orange centre echangeur a7 a9': 465,
#  'aparthotel forest glade': 466,
#  'hotel am untreusee': 467,
#  'ferien appartements am park': 468,
#  'saint gery boutique hotel': 469,
#  'island paradise 8ad - 1 br condo': 470,
#  'bungalows costa esmeralda': 471,
#  'apartamento jávea con jacuzzi y piscina': 472,
#  'acogedora suite monoamb en mendoza 3': 473,
#  'santorini princess luxury spa hotel': 474,
#  'travel charme fürstenhaus am achensee': 475,
#  'landhotel zur post': 476,
#  'mithila hotel': 477,
#  'the plume of feathers - inn': 478,
#  'casa do ivo (paraíso em santarém)': 479,
#  'nh ingolstadt': 480,
#  'hotel su & aqualand': 481,
#  'hilton durban': 482,
#  'hotel tudanca benavente': 483,
#  'copacabana beach hotel acapulco': 484,
#  'an creagán bed and breakfast': 485,
#  'monte pascoal praia hotel': 486,
#  'tiffanys bed & breakfast': 487,
#  'la torretta bobbio': 488,
#  'best western plus cottontree inn': 489,
#  'candlewood suites cotulla': 490,
#  'hotel sercotel suite palacio del mar': 491,
#  'masons arms': 492,
#  'st james of knysna': 493,
#  'mini hotel': 494,
#  'montana': 495,
#  'hotel in': 496,
#  'residenze al castello': 497,
#  'fulnaeum house pension': 498,
#  'sakura terrace the gallery': 499,
#  'hotel encounter nepal': 500,
#  'century park motor lodge': 501,
#  'connemara coast hotel': 502,
#  'sapphire addis hotel': 503,
#  'little fox hotel': 504,
#  'favored hotel plaza': 505,
#  'maison la tour': 506,
#  'summit hermon hotel & spa': 507,
#  'b&b al borgo': 508,
#  'chien ching b&b': 509,
#  'qubus hotel wroclaw': 510,
#  'the bayview hotel': 511,
#  'prestige villas pool yard - campsite': 512,
#  'aequora lanzarote suites': 513,
#  'residhome clermont ferrand gergovia': 514,
#  'homoki lodge': 515,
#  'the inn at fairfield beach': 516,
#  'jolly suites petkasem': 517,
#  'i ventitre passi b&b': 518,
#  'hotel emporio acapulco': 519,
#  'chez dominique': 520,
#  'hotel hanseport hamburg': 521,
#  'youth hostel st. moritz': 522,
#  "le mas des auges chambres d'hôtes": 523,
#  'the benson, a coast hotel': 524,
#  'scandic hamburg emporio': 525,
#  'laumon': 526,
#  'radisson blu hotel, jeddah': 527,
#  'town inn': 528,
#  '133 white sands - 3 br home': 529,
#  'chalet for those who love nature, many opportunities for walking in the area': 530,
#  'althoff hotel fürstenhof celle': 531,
#  'jolly roger hotel': 532,
#  'wox hotel': 533,
#  'hôtel suisse': 534,
#  'thyme for bed': 535,
#  'premiere classe valence nord - saint marcel-lès-valence': 536,
#  'park inn by radisson najran': 537,
#  'petunya konak - boutique class': 538,
#  'les costebelles': 539,
#  'hotel rila sofia': 540,
#  'san pietro boutique rooms': 541,
#  'margaret river tourist park': 542,
#  'apartment with 2 bedrooms in monterenzio, with terrace and wifi': 543,
#  'casa mia': 544,
#  'sagrados corações pousada': 545,
#  'home for creativity - coliving calabria': 546,
#  'aparthotel orchidea': 547,
#  'mola mola resort gili air lombok': 548,
#  'country village hotel': 549,
#  'villa amor': 550,
#  'villas kefalonia': 551,
#  'hotel forza nagasaki': 552,
#  'athens green apartments': 553,
#  'grand bahia principe coba - all inclusive': 554,
#  "boutique hotel d'oude morsch": 555,
#  'hotel color': 556,
#  'catalonia mirador des port': 557,
#  'baita della fontana': 558,
#  'alpenrose bayrischzell hotel & restaurant': 559,
#  'novotel szekesfehervar': 560,
#  'dorfhotel boltenhagen': 561,
#  'dino studio': 562,
#  "chambres d'hôtes le clos du phare": 563,
#  'star inn hotel regensburg zentrum, by comfort': 564,
#  'yoon': 565,
#  'intercontinental fuzhou': 566,
#  'seashell 28 - 2 br condo': 567,
#  'moonfrà': 568,
#  'the farmyard inn': 569,
#  'la quinta #133 - 2 br home': 570,
#  'daphne hotel apartments': 571,
#  'hotel sercotel familia conde': 572,
#  'clearwater beach hotel': 573,
#  'escapesuite': 574,
#  'la casablanca hotel': 575,
#  'hotel & apartments zarenhof berlin mitte': 576,
#  'tulip inn eindhoven airport': 577,
#  'machi de kurasu tengachaya-3': 578,
#  'hotel inn design dijon': 579,
#  'posthotel rotenburg': 580,
#  'tembo house hotel & apartments': 581,
#  'celebrity apartments brighton queens': 582,
#  'beautiful home with red rock view': 583,
#  'rufford arms hotel': 584,
#  'croghan road self catering': 585,
#  'la villa duflot': 586,
#  'château de varennes': 587,
#  'studio medicis sleepngo': 588,
#  'atn hotel': 589,
#  'mint house in germantown': 590,
#  'wellnesshotel till moyland': 591,
#  'radisson blu resort & spa, cesme': 592,
#  'hotel le betulle': 593,
#  'marconfort atlantic gardens bungalows - adults only': 594,
#  'hotel sonnenhof': 595,
#  'hotel manufaktura': 596,
#  'warsawrent apartments centralna': 597,
#  'rose city motel': 598,
#  'alana royal hotel': 599,
#  "hotel cava dell'isola": 600,
#  'memoire siem reap hotel': 601,
#  'travel charme nordperd & villen göhren': 602,
#  'water view 201 - 2 br condo': 603,
#  'hotel eurogarden': 604,
#  'hotel vista': 605,
#  'bed & breakfast opperdoes': 606,
#  'fortune select grand ridge-member itc hotel group': 607,
#  'leonardo royal hotel frankfurt': 608,
#  'cemarim hotel': 609,
#  'th hotel penang': 610,
#  'casa caribe b&b': 611,
#  'de bois en bois': 612,
#  'hotel r de paris': 613,
#  'big4 seymour holiday park': 614,
#  'newton villa': 615,
#  'petit palace hotel tres': 616,
#  'masseria santa lucia': 617,
#  'griya batik giri sekar homestay': 618,
#  'centro hotel residence': 619,
#  'bergland hotel': 620,
#  'ab apartment 45': 621,
#  'moroccan house hotel casablanca': 622,
#  'wyndham san diego bayside': 623,
#  'cezanne hotel': 624,
#  'hotel alba': 625,
#  'summer garden guest house (the palms)': 626,
#  'uniqato': 627,
#  'hotel liberty': 628,
#  'espectacular ático al lado del mar': 629,
#  'rest guesthouse': 630,
#  'kairaba mirbat resort': 631,
#  'prestige inn & suites extended stay': 632,
#  'west central apartment': 633,
#  'jufa hotel spital am pyhrn': 634,
#  'tong tin tat residence view': 635,
#  "canberra's white house": 636,
#  'landgasthaus-hotel wenninghoff': 637,
#  'ocean lodge santa monica beach hotel': 638,
#  'solar madariaga': 639,
#  'vessel inn hiroshima ekimae': 640,
#  'leonardo hotel bad kreuznach': 641,
#  'holiday inn london - heathrow t5': 642,
#  'ferien- und gästehaus wilma': 643,
#  'indigo mare hotel apartments': 644,
#  'dropiluc': 645,
#  'az hôtel zeralda': 646,
#  'maritim hotel königswinter': 647,
#  'best western plus kingston hotel and conference center': 648,
#  'hampton villa motel': 649,
#  'smart hotel garnizon': 650,
#  'europe hotel': 651,
#  'hostaway': 652,
#  'my pad provence 2': 653,
#  'parker guest house san francisco': 654,
#  'asanoya': 655,
#  'domaine de fontète - gites': 656,
#  'house one guesthouse': 657,
#  'homehotel walking to trains, westfield & cinema': 658,
#  'casa rural mas violella': 659,
#  'country inn & suites by radisson, bentonville south - rogers, ar': 660,
#  'oft san conrado hotel': 661,
#  'berghotel randolins': 662,
#  'bright riverside holiday park': 663,
#  'terra maria': 664,
#  'hotel cigno': 665,
#  'city-hotel-garni-diez': 666,
#  'la genzianella': 667,
#  'villa olmi firenze': 668,
#  "chambre d'hotes la saisonneraie": 669,
#  'hagihonjin': 670,
#  'hotel amaryllis veurne': 671,
#  'radisson blu hotel, kiev': 672,
#  'château de la grèze': 673,
#  'key largo inn, a smoke-free property': 674,
#  'mas de tenesa': 675,
#  'hotel gran belveder': 676,
#  "'t kasteel en 't koetshuys": 677,
#  'etazhy bibliotechnaya-komsomolskaya': 678,
#  'hotel cristóbal colón': 679,
#  'home away from home': 680,
#  'hotel vila galé atlântico': 681,
#  'stacci rural resort': 682,
#  'le rime': 683,
#  'uy proa sur hotel': 684,
#  'grand hotel gallia & londres': 685,
#  'portobay búzios': 686,
#  'intercontinental presidente cancun resort': 687,
#  'la veranera guest house': 688,
#  'dormy inn premium otaru natural hot spring': 689,
#  'hotel das américas': 690,
#  'károlyi kastély hotel & restaurant': 691,
#  'zen boutique apart hotel': 692,
#  'plasencia plaza mayor luxury': 693,
#  'san bosco inn': 694,
#  'kalima resort & spa, phuket': 695,
#  'motel 6 bricktown': 696,
#  "lindsey's resort": 697,
#  'appartement maria': 698,
#  'hotel harvest kinugawa': 699,
#  'tokyo daiichi hotel matsuyama': 700,
#  'vitalhotel am stadtpark': 701,
#  "b&b l'ortodellerose": 702,
#  'sara resort': 703,
#  'fulufjällsgården': 704,
#  'royal sarovar portico': 705,
#  'mojo nomad aberdeen harbour': 706,
#  'residenza ognissanti': 707,
#  'casa galos hotel & lofts': 708,
#  'imabari kokusai hotel': 709,
#  'pousada dos frades': 710,
#  'the house of edward': 711,
#  'holiday inn express inn & suites searcy': 712,
#  'le magic hall': 713,
#  'hotel brockenblick': 714,
#  'kiwi studios motel': 715,
#  'la posada de san marcos': 716,
#  'casa rural la puria': 717,
#  'la quinta #112 - 3 br condo': 718,
#  'villa il conte': 719,
#  'echi di puglia': 720,
#  'towneplace suites by marriott aberdeen': 721,
#  'polfearn chalet': 722,
#  'zante view studios': 723,
#  'hotel meridian': 724,
#  'residence mareblu': 725,
#  'greenacre villas - sydney': 726,
#  'primus hotel shanghai sanjiagang - pudong international airport / disney': 727,
#  'gîte la loge des fées': 728,
#  'bubinzana magical lodge': 729,
#  'moness resort': 730,
#  'rezydencja nosalowy dwór': 731,
#  'zoetry paraiso de la bonita riviera maya all inclusive': 732,
#  'atc železná ruda apartments': 733,
#  'penzión tiberia': 734,
#  'vitasol park': 735,
#  "chambres d'hotes chaumeil": 736,
#  'old west lofts down town tampa': 737,
#  'gasthaus kreuz': 738,
#  'gallery nozawa inn': 739,
#  'als kloster bed & breakfast': 740,
#  'wheelwrights arms': 741,
#  'gran hotel domine bilbao': 742,
#  'villa nova': 743,
#  'aux reves des mees': 744,
#  'seadust cancun family resort - all inclusive': 745,
#  'hotel la bastide saint martin': 746,
#  'aiolos villas': 747,
#  'boutique hostel forum': 748,
#  'hotel floresta': 749,
#  'abakan': 750,
#  'hirosaki park hotel': 751,
#  'hôtel gambetta': 752,
#  'hotel urune': 753,
#  'frankair star hotel frankfurt airport': 754,
#  'la fête en provence - chambres': 755,
#  'hotel torbräu': 756,
#  'janjao hotel': 757,
#  'barrio café hotel': 758,
#  'the barrymore hotel tampa riverwalk': 759,
#  'youth hostel richterswil': 760,
#  'posada amor hotel boutique': 761,
#  'red feather lodge': 762,
#  "hôtel l'arboisie": 763,
#  "chambres d'hôtes moulin du david": 764,
#  'venesis house': 765,
#  '305 manor gardens': 766,
#  'the glendeveor': 767,
#  'casa dann carlton hotel & spa': 768,
#  'h10 ocean dunas - adults only': 769,
#  'come friday cottages on the bay': 770,
#  'hotel 1620 plymouth harbor': 771,
#  'pension megumiyuki': 772,
#  'life gallery': 773,
#  'zatoka komfortu blueapart jastarnia': 774,
#  'parador de ronda': 775,
#  'hotel maranello village': 776,
#  'a&m lodging house': 777,
#  'cheddar house unit 123 3 bedrooms 2 bathrooms home': 778,
#  'ecton house': 779,
#  'viajero posada b&b': 780,
#  'the ibnii spa resort': 781,
#  "gigli d'oro suite": 782,
#  'hotel conquistador inn by us consulate': 783,
#  'dormitory sandanya guesthouse': 784,
#  'casa vacanze poggio delle rose': 785,
#  'blue ocean apartment in lanzarote': 786,
#  'kingston mclean': 787,
#  'pullman jakarta indonesia': 788,
#  'sunrise montemare resort - adults only': 789,
#  'pudra hotel': 790,
#  'melangel': 791,
#  'bcons hotel binh duong': 792,
#  'apartment royal viii': 793,
#  "sant'antonino": 794,
#  'the emerald resort noosa': 795,
#  'hotel vila gale praia': 796,
#  '200 year old swiss house': 797,
#  'chanwu hotel - dengfeng': 798,
#  'hotel santika mega city bekasi': 799,
#  'foxy crocodile bush retreat': 800,
#  'hiraizumi hotel musashibou': 801,
#  'h10 conquistador': 802,
#  'romantik hotel braunschweiger hof': 803,
#  'casa roberto': 804,
#  'hotel erbprinz': 805,
#  'the george at yering': 806,
#  'apartamentos metro pasarela': 807,
#  'hotel castellum': 808,
#  'beachfront at sandestin': 809,
#  'hotel st. georg zum see': 810,
#  'quintessa hotel sasebo': 811,
#  'palais saleya boutique hôtel': 812,
#  "fanny's": 813,
#  'park hotel cilento': 814,
#  'checkincheckout - loulé city center apartment 3': 815,
#  'leonardo hotel düsseldorf city center': 816,
#  'house with 2 bedrooms in la porcherie, with enclosed garden and wifi': 817,
#  'hotel pasatiempo': 818,
#  'snowline 13 by redawning': 819,
#  'the mill house': 820,
#  'hotel city green berlin': 821,
#  'dreamhost apartments at collins': 822,
#  'fiesta americana condesa cancun - all inclusive': 823,
#  'hotel delle cave': 824,
#  'brown hare cottage': 825,
#  'brocks guest house': 826,
#  'b&b prà de mandè': 827,
#  'risorgimento resort': 828,
#  'holiday home fjätervålen fjätstigen': 829,
#  "la cour d'hortense": 830,
#  'lobinger hotel parkhotel': 831,
#  'g hotel': 832,
#  'relax a lodge': 833,
#  'primrose cottage': 834,
#  "riad hel'lo": 835,
#  'an den ufergärten': 836,
#  'les baladines residence tourisme': 837,
#  'hôtel héraclée': 838,
#  'ferienhaus hostel salta': 839,
#  'hotel restaurant la sonnerie': 840,
#  'hotel isabella': 841,
#  'sala samui chaweng beach resort': 842,
#  "chez barrak - chambre d'hôte": 843,
#  'turaco lodge': 844,
#  'la casa griunit': 845,
#  'checkvienna - reschgasse': 846,
#  'best western alexander park chambéry': 847,
#  'ruidoso mountain inn': 848,
#  'triton': 849,
#  'total valencia white': 850,
#  'el dorado casitas royale, gourmet all inclusive by karisma': 851,
#  'apartmány weissov dom': 852,
#  'hotel porta nigra': 853,
#  'bq can picafort hotel': 854,
#  'aryaduta bandung': 855,
#  "morra's home": 856,
#  'ruidoso river park - two bedroom cabin': 857,
#  'pension waldstraße': 858,
#  'the tea garden': 859,
#  'yo1 wellness resort and spa': 860,
#  'guest house sibirskiy': 861,
#  'hotel restaurant brügge': 862,
#  'la fusteria del casat': 863,
#  'maritim hotel gelsenkirchen': 864,
#  'stella village hotel & bungalows - all inclusive': 865,
#  'almrefugio': 866,
#  'blue lagoon city hotel': 867,
#  'sol la palma hotel': 868,
#  'stay here nd apartments': 869,
#  'la terra dei sogni country hotel': 870,
#  'burgus tribute & design hotel': 871,
#  'prestige goya park': 872,
#  'hotel royal saint honoré': 873,
#  'giardini reali': 874,
#  'pirates lair pb215 2 bedrooms 2 bathrooms condo': 875,
#  'cambie lodge b&b': 876,
#  'tentrr - hidden brook farm': 877,
#  'olympic lagoon resort paphos - all inclusive': 878,
#  'studio by tripvillas holiday homes': 879,
#  'acacias étoile': 880,
#  'jago gili air': 881,
#  'la quinta #122 - 2 br home': 882,
#  'guesthouse trogir proto': 883,
#  'the luxton bandung': 884,
#  'wellness&restaurant u fandy': 885,
#  'hollins wood bothy': 886,
#  'hotel-pension fent': 887,
#  'belle etage by studiotel': 888,
#  'lagoon view apartments -adults only': 889,
#  'bubble 8': 890,
#  'hotel da música': 891,
#  'toldi apartments': 892,
#  'meliá century hotel ponce': 893,
#  'hotel granvia hiroshima': 894,
#  'the bamboo leaf yangshuo': 895,
#  'rimske terme - hotel zdraviliški dvor': 896,
#  'country inn & suites by radisson, matteson, il': 897,
#  'penzion krumlov - b&b hotel': 898,
#  'maritina hotel': 899,
#  'adc design apartmány': 900,
#  'apartment with 2 bedrooms in borgo a buggiano, with furnished terrace and wifi - 51 km from the beach': 901,
#  'ace hôtel montluçon': 902,
#  'résidence pinarello': 903,
#  'marloth kruger accommodation': 904,
#  'hotel creusen': 905,
#  'palau dels osset': 906,
#  'hôtel de brienne': 907,
#  'hotel boutique casareyna': 908,
#  'villa e palazzo aminta hotel beauty and spa': 909,
#  'the cliffs at peace canyon': 910,
#  'hotel botanico san lazzaro': 911,
#  'hampton inn russellville': 912,
#  'padley farm b&b': 913,
#  'pipers run 8 3 br condo by redawning': 914,
#  'hyltena stugby - campground': 915,
#  'hôtel barrière le majestic cannes': 916,
#  'hotel gasperin': 917,
#  'gorgeous apartments in the city': 918,
#  'sunborn gibraltar': 919,
#  'forfar house unit 0148 4 bedrooms 3 bathrooms home': 920,
#  'champs elysees plaza hotel': 921,
#  "gyeong's hostel": 922,
#  'hotel balmoral - champs elysees': 923,
#  'margutta 19 - small luxury hotels of the world': 924,
#  'decanter hotel': 925,
#  'water view 404 - 2 br condo by redawning': 926,
#  'séjours & affaires poitiers lamartine': 927,
#  'sala samui choengmon beach': 928,
#  'hotel steinbock': 929,
#  'grand hotel forlì': 930,
#  'homely apartments zammit': 931,
#  'hotel broad ripple at river house': 932,
#  'teatro verdi hotel': 933,
#  'tourist lodge gansbaai': 934,
#  'baymont by wyndham cotulla': 935,
#  'radisson blu royal hotel, bergen': 936,
#  'belltown court home port deluxe suite - two bedroom apartment with balcony': 937,
#  "le clos zinou chambres d'hotes": 938,
#  'moselebauer': 939,
#  'windsor califórnia hotel': 940,
#  'le mas des roches': 941,
#  'london city view': 942,
#  'hotel-steakhouse cheminée': 943,
#  'le domaine des ramonets': 944,
#  'fullon taipei central (daan park)': 945,
#  'bel poggio country house standard and luxury': 946,
#  '3 pieces tout confort parking saint jean': 947,
#  'd. hotel suites & spa': 948,
#  'rødvig kro og badehotel': 949,
#  'terral hotel & spa': 950,
#  'mito plaza hotel': 951,
#  'ruster resort': 952,
#  'hotel magnus': 953,
#  'hotel emiran': 954,
#  'histórico central mexico city': 955,
#  'sapienza time': 956,
#  'ibis braganca': 957,
#  'hotel rich&garden sakata': 958,
#  'eilatsuites apartments': 959,
#  'frida village': 960,
#  'hotel schepers': 961,
#  'hotel kompas': 962,
#  'hotel schloss spyker': 963,
#  'watermark luxury oceanfront all suite hotel': 964,
#  'seehotel das traunsee': 965,
#  'infinity views village': 966,
#  'mango tree guest house': 967,
#  'landsberger hof': 968,
#  'kaishen hotel': 969,
#  'barbarella suite': 970,
#  'auberge de la langouste': 971,
#  'hotel route-inn mitokenchomae': 972,
#  'ibis los mochis': 973,
#  'novum hotel belmondo hamburg hbf.': 974,
#  'auberge de la gare': 975,
#  'intercity berrini': 976,
#  'arrecife': 977,
#  'raise hotel taichung': 978,
#  'relais colonna': 979,
#  'radisson blu hotel, birmingham': 980,
#  'su carru a boi': 981,
#  'b&b - i corni di nibbio': 982,
#  'newhall mains, red gates': 983,
#  'sanborn guest house': 984,
#  'zur altstadt': 985,
#  'lewinnick lodge': 986,
#  'b&b sasput': 987,
#  'the himalayan': 988,
#  'miura hotel': 989,
#  'the serai cottage boutique hotel': 990,
#  'mint hotel': 991,
#  'séjours & affaires paris bagneux': 992,
#  'relais vignale & spa': 993,
#  'beach palms 204 - 3 br home': 994,
#  'hotel gratschwirt': 995,
#  'affittacamere volusia house': 996,
#  'lakeside waterfront apartment 18': 997,
#  'charmilles des cordeliers': 998,
#  'pension fialka': 999,
#  ...}
